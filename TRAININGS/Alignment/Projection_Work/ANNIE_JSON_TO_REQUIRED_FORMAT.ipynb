# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiamakac/TRAININGS/blob/main/TRAININGS/Alignment/Projection_Work/ANNIE_JSON_TO_REQUIRED_FORMAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -c https://raw.githubusercontent.com/Chiamakac/TRAININGS/main/Alignment/Projection_Work/COMPARE.txt
# Out:
# --2022-07-11 16:55:54--  https://raw.githubusercontent.com/Chiamakac/TRAININGS/main/Alignment/Projection_Work/COMPARE.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37164 (36K) [text/plain]
# Saving to: ‘COMPARE.txt’
#
# COMPARE.txt         100%[===================>]  36.29K  --.-KB/s    in 0.004s
#
# 2022-07-11 16:55:54 (8.87 MB/s) - ‘COMPARE.txt’ saved [37164/37164]

# %%
import json
import numpy as np
def replace_substr(oldstr, indices, newstr):
  beg, end = indices
  string = oldstr[:beg] + newstr +" "+ oldstr[end+1:]
  # print(string)
  return string, beg+len(newstr)-end
data = json.load(open('/content/COMPARE.txt'))
text = data['text']
indices_tags = []
for entity, value in data['entities'].items():
  # print(entity)
  for el in value:
    beg, end = el['indices'][0], el['indices'][1]
    tag = f"[{text[beg:end]}_{entity}]".replace(' ','_')
    indices_tags.append((el['indices'], tag))

# %%
shift = 0
for ind, tag in sorted(indices_tags):
  indices, str_tag = ind, tag
  indices = np.array(indices) + shift
  text, new_shift = replace_substr(text, indices, str_tag)
  shift += new_shift

# %%
tags = ("\n".join(text.split()))

# %%
print(tags)
# Out:
# [Pius_Adesanmi_To_Person]
# Be
# Buried
# On
# [Saturday_Date]
# [Adesanmi_Person]
# born
# [February_27,_1972_Date]
# was
# author
# of
# the
# popular
# book
# Naija
# No
# Dey
# [Carry_Last_Person]
# a
# [2015_Date]
# collection
# of
# satirical
# essays.
# The
# family
# of
# late
# Prof
# [Pius_Adesanmi_Person]
# has
# announced
# the
# burial
# of
# the
# Nigerian-born
# Canadian
# scholar,
# writer,
# literary
# critic
# and
# columnist,
# who
# died
# on
# [March_10,_2019_Date]
# when
# an
# Ethiopian
# Airline
# aircraft
# crashed
# shortly
# after
# take-off.
# [Adesanmi_Person]
# born
# [February_27,_1972_Date]
# was
# author
# of
# the
# popular
# book
# Naija
# No
# Dey
# [Carry_Last_Person]
# a
# [2015_Date]
# collection
# of
# satirical
# essays.
# [Adesanmi_Person]
# was
# a
# [Fellow_Organization]
# of
# the
# French
# Institute
# for
# Research
# in
# [Africa_Location]
# [from_1993_to_1997_Date]
# and
# of
# the
# [French_Institute_of_South_Africa_Organization]
# in
# [1998_Date]
# and
# [2000_Date]
# [From_2002_to_2005_Date]
# he
# was
# Assistant
# Professor
# of
# Comparative
# Literature
# at
# the
# [Pennsylvania_State_University_Organization]
# [United_States_Location]
# In
# [2006_Date]
# he
# joined
# [Carleton_University_Organization]
# in
# [Ottawa_Location]
# [Canada_Location]
# as
# a
# professor
# of
# Literature
# and
# African
# Studies.
# He
# was
# the
# director
# of
# the
# university's
# [Institute_of_African_Studies_Organization]
# until
# his
# death.
# Players,
# Coaching
# Staff
# Of
# [Southampton_Location]
# To
# Donate
# Wages
# After
# 9-0
# Hammering
# By
# [Leicester_Location]
# [Southampton_Location]
# play
# League
# Cup
# holders,
# [City_Location]
# in
# the
# fourth
# round
# of
# the
# competition
# on
# [Tuesday_Date]
# and
# are
# back
# there
# on
# [Saturday_Date]
# for
# a
# [Premier_Organization]
# League
# clash.
# I
# have
# said
# it
# million
# times,
# in
# [20_Date]
# years,
# we
# are
# going
# to
# see
# the
# reward
# of
# our
# investments.
# Mide
# Ayeni
# is
# the
# Founder
# of
# [Pearl_Recycling_Person]
# a
# sustainable
# eco-furniture
# company
# in
# [Nigeria_Location]
# She
# is
# a
# [US_Department_of_States_Techwomen_Fellow_Organization]
# The
# Teflon
# President
# With
# Nine
# Lives
# Is
# On
# His
# Way
# Out
# By
# [Dr._Wumi_Akintide_Person]
# The
# Teflon
# outlaw
# with
# 9
# lives
# came
# to
# town
# promising
# to
# undo
# everything
# [Obama_Person]
# has
# done
# while
# promising
# to
# “make
# [America_Location]
# great
# again,”
# as
# if
# [America_Location]
# has
# ever
# at
# any
# time
# lost
# her
# greatness
# following
# the
# end
# of
# the
# Second
# World
# War.
# You
# probably
# know
# who
# I
# am
# talking
# about.
# The
# Teflon
# President
# with
# nine
# lives
# I
# have
# in
# mind
# is
# nobody
# else
# but
# [Donald_J._Trump_Person]
# Can
# any
# of
# you
# reading
# this
# write-up
# imagine
# [Barack_Obama_Person]
# who
# twice
# won
# the
# popular
# vote
# and
# the
# [Electoral_College_Organization]
# tallies
# and
# who
# spent
# 8
# good
# years
# in
# the
# [White_House_Organization]
# without
# a
# single
# scandal,
# being
# described
# as
# a
# cat
# with
# 9
# lives?
# Not
# by
# a
# long
# shot.
# The
# answer
# to
# the
# rhetorical
# question
# has
# to
# be
# a
# resounding
# no.
# Poor
# [Obama_Person]
# as
# President
# of
# the
# [United_States_Location]
# would
# long
# have
# been
# skinned
# alive
# and
# sacrificed
# to
# the
# gods
# by
# the
# [Republicans_Organization]
# who
# obstructed
# him
# every
# step
# of
# the
# way
# during
# all
# of
# his
# 8
# years
# in
# the
# [White_House_Organization]
# all
# in
# the
# name
# of
# partisan
# politics.
# You
# would
# have
# thought
# they
# would
# have
# left
# him
# off
# the
# hook
# the
# moment
# he
# left
# office,
# but
# [Republicans_Organization]
# and
# their
# Narcissist-in-Chief
# in
# the
# [White_House_Organization]
# have
# not
# left
# [Obama_Person]
# alone
# for
# one
# brief
# moment.
# In
# fact,
# the
# grossly
# ignorant
# and
# incompetent
# lunatic
# in
# the
# [White_House_Organization]
# still
# finds
# some
# ways
# to
# blame
# [Obama_Person]
# or
# [Hillary_Person]
# even
# for
# some
# of
# his
# own
# insanity
# or
# foolishness
# while
# fraudulently
# claiming
# to
# be
# the
# smartest
# [President_America_Person]
# has
# ever
# put
# in
# office.
# [Adesanmi_Person]
# born
# [February_27,_1972_Date]
# was
# author
# of
# the
# popular
# book
# Naija
# No
# Dey
# [Carry_Last_Person]
# a
# [2015_Date]
# collection
# of
# satirical
# essays.
# [Adesanmi_Person]
# was
# a
# [Fellow_Organization]
# of
# the
# French
# Institute
# for
# Research
# in
# [Africa_Location]
# [from_1993_to_1997_Date]
# and
# of
# the
# [French_Institute_of_South_Africa_Organization]
# in
# [1998_Date]
# and
# [2000_Date]
# [From_2002_to_2005_Date]
# he
# was
# Assistant
# Professor
# of
# Comparative
# Literature
# at
# the
# [Pennsylvania_State_University_Organization]
# [United_States_Location]
# BISHOP
# [AMATU_Person]
# BURIES
# 96-YEAR-OLD
# MUM
# By
# [Regina_Igwebuike_Person]
# In
# a
# welcome
# address,
# School
# Manager,
# [Rev._Fr_Person]
# [Michael_Adawai_Person]
# said
# they
# applied
# holistic
# approach
# to
# children’s
# educational
# development,
# noting
# that
# they
# had
# zero
# tolerance
# for
# cultism.
# She
# thanked
# management
# of
# [St._Edmund_Person]
# Group
# of
# schools
# for
# going
# extra
# the
# mile
# to
# borrow
# [St_Person]
# [Alphonsus_Catholic_Church_Organization]
# Nkpor
# sporting
# ground
# to
# accommodate
# all
# sporting
# events.
# [Lady_Lizzy_Ewuzie_Person]
# [Area_Education_Organization]
# Officer
# (AEO),
# Idemili
# North
# represented
# the
# commissioner
# at
# the
# event.
# According
# to
# the
# commissioner
# said
# sports
# help
# in
# mental,
# physical
# and
# psychological
# development
# of
# learners,
# stressing
# that
# properly
# engaging
# youths
# in
# sports
# will
# make
# them
# lose
# interest
# in
# social
# vices.
# 7,
# [2020_Date]
# (MOI)
# [Catholic_Organization]
# Bishop
# of
# Okigwe
# [Diocese_Person]
# Imo
# [State_Organization]
# Most
# [Rev._Solomon_Amatu_Person]
# accompanied
# by
# family
# and
# friends,
# bid
# farewell
# to
# his
# late
# mother,
# [Mrs_Rebecca_Mgboye_Amatu_Person]
# aged
# 96.
# [Prof._Omenugha_Person]
# made
# the
# call
# during
# Inter-house
# sports
# competition
# organised
# by
# [St._Edmund_Person]
# [Group_of_Schools_Organization]
# Nkpor.
# The
# deceased
# was
# born
# on
# [Feb._14,_1923_Date]
# into
# family
# of
# late
# Pa/[Mrs_Anakonwa_Person]
# of
# [Oranto_Village_Location]
# married
# to
# late
# [Pius_Amatu_Person]
# of
# Obinagu
# [Akpu_Village_Location]
# both
# in
# Ukpo.
# [SCHOOLS_Organization]
# URGED
# TO
# PROMOTE
# SPORTS,
# CURB
# CULTISM
# AS
# [ST_Person]
# EDMUND
# [SCHOOLS_Organization]
# NKPOR
# HOLD
# INTER-HOUSE
# SPORTS
# Speaking
# while
# concelebrating
# the
# burial
# Mass
# at
# [St._Simon_Person]
# [Catholic_Church_Organization]
# Ukpo,
# Most
# [Rev._Paulinus_Ezeokafor_Person]
# [Catholic_Organization]
# Bishop
# of
# [Awka_Diocese_Person]
# said
# that
# burying
# the
# dead
# was
# one
# of
# the
# ``corporal
# works
# of
# mercy’’.
# Nkpor
# (Idemili
# [North_LGA_Location]
# ,
# [Feb._25,_2020_Date]
# (MOI)
# Anambra
# [State_Organization]
# Commissioner
# for
# [Basic_Education_Organization]
# [Prof._Kate_Omenugha_Person]
# has
# urged
# private
# and
# public
# schools
# to
# promote
# sports
# as
# panacea
# against
# cultism
# and
# other
# vices
# among
# youths.
# [Mr_Emmanuel_Nwafor_Person]
# member
# representing
# Orumba
# [South_Constituency_Location]
# suggested
# proper
# checking
# of
# the
# seals
# of
# the
# consultants
# in
# other
# to
# ascertain
# their
# level
# of
# authenticity
# because
# fake
# seals
# abound.
# [Ezeokafor_Person]
# added
# that
# the
# deceased
# lived
# her
# life
# in
# the
# hope
# of
# resurrection,
# which
# was
# a
# fulfillment
# of
# what
# we
# believe
# in
# as
# Christians.
# He
# emphasised
# that
# death
# was
# an
# answered
# prayer
# as
# one
# transcended
# from
# temporal
# life
# to
# eternity
# to
# live
# at
# peace
# with
# God.
# The
# prelate
# noted
# that
# [Mrs_Amatu_Person]
# was
# energetic,
# beautiful
# as
# well
# as
# a
# good
# singer
# with
# a
# golden
# voice.
# She
# was
# a
# notable
# lead
# singer
# in
# all
# ceremonies
# and
# activities
# in
# her
# town
# and
# beyond,
# which
# merited
# her
# name
# `Onu
# Ogene’.
# He
# explains:
# ``life
# is
# a
# gift
# from
# God,
# which
# must
# be
# respected’’,
# urging
# those
# who
# fail
# to
# take
# care
# of
# their
# parents
# at
# old
# age
# to
# retrace
# their
# steps
# so
# as
# to
# reap
# God’s
# promise
# of
# long
# life’’.
# One
# of
# the
# deceased
# sons,
# Most
# Rev.
# [Solomon_Amatu_Person]
# said
# that
# his
# mother
# was
# non
# believer
# and
# became
# a
# Christian
# convert
# in
# [1962_Date]
# to
# [Christ_Apostolic_Church_Organization]
# ([CAC_Organization]
# as
# a
# result
# of
# miraculous
# healing
# of
# her
# husband
# when
# he
# was
# down,
# bedridden
# after
# attending
# a
# crusade.
# [Bishop_Amatu_Person]
# noted
# that
# she
# was
# an
# ardent
# and
# devout
# member
# of
# [CAC_Organization]
# until
# [2003_Date]
# when
# she
# became
# a
# [Catholic_Organization]
# faith
# after
# his
# Episcopal
# Ordination.
# According
# to
# him,
# she
# embraced
# the
# conversion
# and
# convincingly
# remained
# ardent
# and
# devoted
# to
# it
# until
# her
# last
# breath,
# praying
# God
# for
# a
# repose
# of
# her
# soul.
# Anambra
# [State_Organization]
# Governor,
# [Willie_Obiano_Person]
# who
# attended
# the
# event,
# commiserated
# with
# [Amatu_Person]
# family,
# praying
# God
# to
# grant
# them
# the
# fortitude
# to
# bear
# the
# irreparable
# loss.
# Gov.
# [Obiano_Person]
# thanked
# those,
# who
# came
# to
# pray
# for
# the
# deceased’s
# soul,
# especially
# those
# who
# came
# from
# far
# places,
# praying
# God
# to
# grant
# them
# journey
# mercies.
# He
# noted
# that
# the
# state
# was
# enjoying
# security
# to
# the
# glory
# of
# God.
# Delivering
# a
# tribute
# at
# the
# grave
# side,
# [Dr_Solomon_Anigbankpu_Person]
# on
# behalf
# of
# the
# deceased’s
# grand/great
# grandchildren
# said
# that
# grandma
# knew
# precisely
# what
# good
# education
# could
# do
# to
# anyone,
# who
# persisted
# to
# the
# end.
# She
# believes
# that
# it
# is
# better
# to
# develop
# common
# sense
# first
# before
# western
# education
# to
# avoid
# behaving
# and
# acting
# like
# a
# child.
# She
# lived
# a
# life
# of
# prayer,
# selfless
# service,
# high
# sense
# of
# responsibility
# and
# charity,
# humility,
# hard
# work,
# tenacity
# and
# doggedness.
# Her
# prayer
# life
# is
# infectious
# and
# you
# can
# never
# stay
# with
# her
# without
# being
# infected,’’
# he
# emphasised.
# Dignitaries
# at
# the
# ceremony
# include
# [Archbishop_Valerian_Okeke_Person]
# of
# Onitsha
# Archdiocese,
# Owerri
# Provincial
# Bishops,
# a
# former
# Governor
# of
# Anambra
# [State_Organization]
# [Mr_Peter_Obi_Person]
# A
# former
# INEC
# Chairman,
# Prof
# [Maurice_Iwu_Person]
# Anambra
# Commissioner
# for
# [Women_Affairs_Organization]
# [Mrs_Ndidi_Mezue_Person]
# Traditional
# Rulers
# and
# people
# from
# all
# walks
# of
# life
# attended
# too.
# [GOVERNMENT_Organization]
# DONATES
# LAND
# FOR
# PERMANENT
# SITE
# OF
# [AWKA_DIVISION_Organization]
# OF
# COURT
# OF
# [APPEAL_Organization]
# By
# [John_Ndu_Person]
# Okwuosa
# explained
# that
# most
# buildings
# within
# the
# old
# [Awka_Organization]
# were
# built
# several
# years
# ago,
# hence
# the
# disorderly
# nature
# of
# most
# villages.
# 6,
# [2020_Date]
# (MOI)
# Anambra
# [State_Organization]
# [Government_Organization]
# has
# donated
# a
# parcel
# of
# land
# on
# which
# a
# permanent
# site
# on
# which
# the
# Federal
# Judiciary
# can
# build
# the
# [Awka_Organization]
# Division
# of
# Court
# of
# Appeal.
# Gov.
# [Willie_Obiano_Person]
# announced
# this
# while
# receiving
# Judges
# and
# staff
# members
# of
# the
# judiciary,
# led
# by
# President
# of
# Court
# of
# Appeal,
# [Justice_Zainab_Bulkachuwa_Person]
# at
# the
# Governor''s
# Lodge,
# Amawbia.'
# This
# will
# entail
# serious
# demolition.
# Receiving
# the
# delegation,
# Gov.
# [Obiano_Person]
# said
# his
# administration
# would
# always
# provide
# necessary
# facilities
# that
# would
# enhance
# prompt
# dispensation
# of
# justice.
# Compensation
# will
# be
# paid
# by
# the
# state
# government
# in
# order
# to
# get
# [Awka_Organization]
# to
# become
# a
# standard
# city.
# The
# governor
# said
# that
# arrangements
# had
# been
# finalised
# for
# procurement
# of
# stenograph
# for
# judges
# to
# facilitate
# justice
# delivery.
# He
# announced
# that
# it
# would
# made
# available
# to
# 25
# courts
# in
# the
# first
# batch.
# In
# addition
# to
# procurement
# of
# stenograph,
# Gov.
# [Obiano_Person]
# said
# that
# his
# administration
# would
# train,
# retrain
# judges
# and
# other
# judicial
# staff
# to
# enable
# them
# to
# get
# acquainted
# with
# modern
# system
# of
# justice
# delivery.
# However,
# this
# will
# not
# hinder
# the
# demolition
# of
# any
# building
# that
# poses
# threat
# to
# the
# community.
# My
# administration
# has
# been
# taking
# care
# of
# Judges.
# Their
# welfare
# is
# my
# utmost
# concern.
# I
# cleared
# the
# accumulated
# debt
# owed
# judges
# by
# previous
# administrations.
# Indeed
# it
# is
# a
# milestone
# achievement
# for
# my
# administration
# under
# the
# leadership
# of
# Court
# of
# Appeal
# President,
# [Justice_Zainab_Bulkachuwa_Person]
# I
# sincerely
# appreciate
# your
# support,’’
# [Obiano_Person]
# said.
# The
# governor
# stressed
# that
# his
# administration
# had
# maintained
# robust
# relationship
# among
# the
# three
# arms
# of
# government,
# promising
# to
# ensure
# no
# interference
# and
# adequate
# separation
# of
# duties.
# President,
# [Court_of_Appeal_Organization]
# [Justice_Bulkachuwa_Person]
# said
# that
# process
# for
# the
# inaugurating
# of
# Court
# of
# appeal
# in
# the
# state
# started
# in
# [2018_Date]
# when
# Gov.
# [Obiano_Person]
# set
# up
# a
# five-man
# Court
# of
# [Appeal_Project_Committee_Organization]
# headed
# by
# [Dr_Onyechi_Ikpeazu_Person]
# [SAN_Location]
# She
# urged
# the
# governor
# to
# ensure
# speedy
# upgrade
# of
# the
# structures,
# to
# be
# in
# line
# with
# stipulated
# standards
# of
# Court
# of
# Appeal
# across
# the
# nation.
# Anambra
# Attorney-General
# and
# Commissioner
# for
# Justice,
# [Dr_Uju_Nwogu_Person]
# commended
# the
# president
# for
# her
# support
# at
# ensuring
# the
# success
# of
# the
# event.
# Okwuosa
# lamented
# that
# field
# workers
# were
# usually
# attacked
# and
# injured
# during
# enforcement,
# especially
# at
# Nise,
# Okpuno
# and
# Umuawulu,
# stressing
# that
# as
# their
# worst
# challenge.
# [PRIMARY_HEALTHCARE_AGENCY_Organization]
# ANNOUNCES
# [2020_Date]
# FIRST
# ROUND
# NIPDS
# By
# Nnedinma
# [C_Okeke_Person]
# He
# added
# that
# development
# control
# would
# entail
# site
# visits
# to
# ensure
# that
# work
# would
# be
# going
# on
# as
# approved.
# Consultants
# in
# the
# building
# industry
# are
# expected
# to
# append
# their
# seal
# in
# drawings
# in
# other
# to
# take
# liability
# for
# any
# default
# in
# the
# building
# Okwuosa,
# then,
# explained
# that
# ACTDA
# would
# look
# at
# buildings
# and
# development
# control,
# adding
# that
# building
# control
# involves
# paper
# work
# where
# the
# developer
# is
# expected
# to
# bring
# survey
# plans,
# evidence
# of
# ownership
# and
# power
# of
# attorney.
# 6,
# [2020_Date]
# (MOI)
# Anambra
# [State_Organization]
# [Primary_Healthcare_Development_Agency_Organization]
# (ASPHCDA)
# in
# collaboration
# with
# partner
# agencies
# have
# announced
# [2020_Date]
# first
# round
# of
# National
# Immunisation
# Plus
# Days
# (NIPDs)
# in
# the
# state.
# Executive
# Secretary,
# ASPHCDA,
# [Dr_Chioma_Ezenyimulu_Person]
# made
# the
# announcement
# during
# the
# [State_Social_Mobilisation_Committee_Organization]
# ([SSMC_Organization]
# meeting
# at
# ASPHCDA
# office
# complex,
# [Awka_Organization]
# She
# noted
# that
# the
# event
# which
# was
# always
# held
# between
# [March_Date]
# and
# [April_Date]
# in
# [past_years_Date]
# would
# now
# hold
# We
# are
# confusing
# regulation
# with
# policy.
# There
# was
# a
# determination
# on
# this
# USSD,
# even
# before
# the
# appointment
# of
# the
# Minister,
# he
# stated.
# It
# is
# not
# about
# the
# good
# boy,
# but
# this
# is
# commercial
# and
# the
# normal
# things
# have
# been
# done.
# Operators
# did
# not
# come
# up
# overnight
# to
# charge
# four
# Naira.
# It
# was
# robustly
# deliberated
# upon
# and
# a
# decision
# jointly
# taken
# before
# the
# legal
# instrument
# was
# published
# for
# implementation
# by
# all
# parties
# involved,”
# he
# explained
# further.
# Similarly,
# the
# President
# of
# the
# [Association_of_Telecommunications_Companies_Organization]
# of
# [Nigeria_Location]
# (ATCON),
# Olusola
# Teniola,
# vehemently
# queried
# where
# the
# autonomy
# of
# the
# [NCC_Organization]
# lies
# if
# the
# ministry
# continues
# to
# interfere.
# Teniola
# stated
# that
# the
# [Federal_Government_Organization]
# needed
# to
# allow
# the
# [NCC_Organization]
# s
# independence
# to
# enforce
# decisions
# made,
# especially
# as
# it
# bothers
# on
# the
# development
# of
# the
# telecommunications
# industry.
# Indeed,
# [The_Guardian_Organization]
# checks
# showed
# that
# there
# is
# a
# legal
# basis
# for
# the
# [NCC_Organization]
# s
# intervention
# to
# protect
# telecoms
# service
# consumers
# (i.e.bank
# customers
# who
# use
# USSD
# for
# financial
# transactions).
# Earlier
# in
# his
# keynote
# address
# on
# ``Reforming
# the
# Maritime
# Sector
# in
# Onitsha;
# Priority
# Areas,
# Potential
# Projects
# and
# the
# Way
# Forward,’’
# [Mr_Moghalu_Person]
# noted
# that
# transportation
# was
# indispensable
# in
# the
# World
# [today_Date]
# The
# event
# was
# held
# at
# All
# [Saints_Cathedral_Organization]
# Onitsha.
# According
# to
# him,
# ongoing
# concessionary
# processes
# to
# address
# certain
# issues
# resolved
# that
# they
# will
# continue
# working
# to
# complete
# the
# port
# project.
# [Mr_Moghalu_Person]
# said
# this
# while
# exchanging
# views
# with
# newsmen
# after
# a
# sensitisation
# seminar
# of
# [South_East_Location]
# zone
# stakeholders
# by
# NIWA.
# [NCC_Organization]
# is
# also
# saddled
# with
# the
# responsibility
# of
# promoting
# fair
# competition
# in
# the
# communications
# industry
# and
# protection
# of
# services
# and
# facilities
# providers
# from
# misuse
# of
# market
# power
# or
# anti-competitive
# and
# unfair
# practices
# by
# other
# service
# or
# facilities
# providers
# or
# equipment
# suppliers;
# and
# the
# responsibility
# to
# general
# responsibility
# of
# the
# Commission
# for
# economic
# and
# technical
# regulation
# of
# the
# communications
# industry.
# To
# many
# Nigerians,
# the
# use
# of
# USSD
# sounded
# new,
# but
# checks
# by
# [The_Guardian_Organization]
# showed
# that
# the
# initiative
# has
# been
# in
# effect
# since
# [2014_Date]
# This
# initiative,
# however,
# got
# a
# boost
# [this_year_Date]
# when
# the
# [NCC_Organization]
# did
# a
# determination
# report
# on
# it.
# The
# report
# obtained
# from
# [NCC_Organization]
# s
# website
# termed
# ‘Determination
# of
# USSD
# Pricing,’
# dated
# [July_23,_2019_Date]
# and
# signed
# by
# the
# Executive
# Vice
# Chairman
# of
# the
# Commission,
# Prof.
# Umar
# Danbatta,
# revealed,
# among
# other
# things,
# that
# a
# USSD
# session
# is
# 20
# seconds;
# the
# cost
# of
# a
# USSD
# session
# is
# N1.
# 63K
# the
# price
# floor
# for
# a
# 20
# seconds
# USSD
# service
# is
# N1.
# 63k
# while
# price
# cap
# for
# a
# 20
# Seconds
# USSD
# Session
# is
# N4.
# The
# Determination
# document
# envisaged
# the
# implementation
# of
# the
# USSD
# charges
# by
# the
# mobile
# network
# operators
# (MNOs)
# to
# take
# effect
# from
# [September_1,_2019_Date]
# and
# remains
# valid
# and
# binding
# on
# licensees

# %%
with open ('COMPARED.txt', 'w') as f:
  for words in tags:
    f.write(f"{words}")
