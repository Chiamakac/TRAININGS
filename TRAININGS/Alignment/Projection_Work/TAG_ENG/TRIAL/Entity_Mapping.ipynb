# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiamakac/TRAININGS/blob/main/TRAININGS/Alignment/Projection_Work/TAG_ENG/TRIAL/Entity_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Read in the English text
# 2. Read in the Igbo text
# 3. Read in the English tagged text

# %%
from collections import Counter
import pickle

# %% [markdown]
# **Read and explore NER tagged English text**

# %%
# !wget -c https://raw.githubusercontent.com/Chiamakac/TRAININGS/main/Alignment/Projection_Work/TAG_ENG/spaCy%20en_tags%20corrected%20FINAL%20USED.txt
# !wget -c https://raw.githubusercontent.com/Chiamakac/TRAININGS/main/Alignment/Projection_Work/TAG_ENG/projection_en_bitext.txt
# Out:
# --2022-10-05 09:59:47--  https://raw.githubusercontent.com/Chiamakac/TRAININGS/main/Alignment/Projection_Work/TAG_ENG/spaCy%20en_tags%20corrected%20FINAL%20USED.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2022-10-05 09:59:47--  https://raw.githubusercontent.com/Chiamakac/TRAININGS/main/Alignment/Projection_Work/TAG_ENG/projection_en_bitext.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %%
tagged_sents = open('/content/spaCy en_tags corrected FINAL USED.txt').readlines()
tagged_sents = [tagged.strip() for tagged in tagged_sents]

# %%
len(tagged_sents)
# Out:
# 6633

# %% [markdown]
# View the first 10 entries

# %%
tagged_sents[:10]
# Out:
# ['1, Nigeria, LOC|Omoyele Sowore, PER',
#  '5, Omoyele Sowore, PER|more than 120 days, DATE',
#  '8, Sowore, PER',
#  '12, the middle of the day, DATE',
#  '13, every year, DATE|the end of every year, DATE',
#  '17, today, DATE',
#  '18, 1984, DATE|Nigeria, LOC|Omoyele Sowore, PER',
#  '19, Monaco, LOC|Nigeria, LOC',
#  '31, first, ORDINAL|Omoyele Sowore, PER',
#  '32, 30 million, CARDINAL|Nigerian, NORP']

# %% [markdown]
# **Extract and explore the Igbo text from the En-Ig Bilingual Text**

# %%
def clean_text(text):
  text = text.replace(')','')
  text = text.replace('\\','')
  return text

# %%
lines = open('projection_en_bitext.txt').readlines()
ig_text = []
for line in lines:
  try:
    ig_text.append(line.strip().split("\', ")[1])
  except:
    ig_text.append(line.strip().split('\", ')[1])
[clean_text(t) for t in ig_text[:10]]
# len(ig_text)
# Out:
# ['"Aghọtara m ma ọ bụrụ na ụgwọ ọnwa, ọnụ ụlọ flaatị atọ na SUV zuuru gị ma n\'ihi nkea, kpatara enweghị ebumnobi nye ala ebe amụrụ gị "',
#  "'Mụ onwe m nwere ebumnobi nye Naịjirịa na gunye ndị amaala ọzọ dịka Omoyele Sowore, ndị nke nwerela nkoropụ na mgbahapụ'",
#  '"Ịchọ ntụgharị n\'ebughị egbe ma ọbụ ije ịnapụ gọọmentị ọchịchị n\'ike abụghị ma agaghị abụ ịda iwu"',
#  '"Iguzo mwuli akọnauche nke ndị mmadụ site n\'ịchọ mgbanwe abụghị ịda iwu"',
#  '\'Ọ bụ nkea mere ka ọchịchị onye kwuo uche ya dịka usoro gọọmentị bụ nke a kọwara dịka "gọọmentị nke ndị mmadụ, site na ndị mmadụ ma nyere ndị mmadụ" Ma ọbụghị gọọmentị nke aka ike, site n\'onye aka ike ma nyere ndị ohu\'',
#  "'Ọ bụrụ na ngagharị iwe na ịkpọ ngagharị iwe #Njegharị ugbua bụ ịda iwu, ndị ụlọikpe kwesirila ịma Omoyele Sowore ikpe ka ha jidesiri ya ihe karịrị abalị otu narị na iri abụọ'",
#  '"ya mere, mara na nkịtị ị gbara ma ọbụ iwezụga onwe gị na nsogbu obodo n\'ihe banyere mmegide, mpụ na elezighị ọhanaeze nke ọma emeghị ka ị buru ezigbo mmadụ"',
#  "'I nweghị ezi ọhụhụ ụzọ ma bụrụkwa onye ma maka naanị onwe ya'",
#  '"Ị hụla, ana m ede ihe ederede a maka na mmadụ gwara m ka wepụ ọnụ n\'okwu Sowore ma gbado anya n\'azụmahịa m na whatsapp, m wee chịa ọchị"',
#  "'Ọ gana agụ ihe ederede a, ya mere m agaghị kpọ aha ya ebe uche ọhụhụ ụzọ adabaghị adaba na nkwenye nke m'"]

# %% [markdown]
# **Convert tagged entities into a dict - `tagged_entities`**
#
# This helps with processing each of the lines one at a time

# %%
tagged_entities = {}
for line in tagged_sents:
  lnum, line = line.strip().split(', ', 1)
  tagged_entities[lnum] = line.split('|')
tagged_entities, len(tagged_entities)
# Out:
# ({'1': ['Nigeria, LOC', 'Omoyele Sowore, PER'],
#   '5': ['Omoyele Sowore, PER', 'more than 120 days, DATE'],
#   '8': ['Sowore, PER'],
#   '12': ['the middle of the day, DATE'],
#   '13': ['every year, DATE', 'the end of every year, DATE'],
#   '17': ['today, DATE'],
#   '18': ['1984, DATE', 'Nigeria, LOC', 'Omoyele Sowore, PER'],
#   '19': ['Monaco, LOC', 'Nigeria, LOC'],
#   '31': ['first, ORDINAL', 'Omoyele Sowore, PER'],
#   '32': ['30 million, CARDINAL', 'Nigerian, NORP'],
#   '34': ['EFCC, ORG', 'more than $ 7 billion, MONEY'],
#   '35': ['Wilson Uwujaren, PER',
#    'Mohammed Idris, PER',
#    'December 2019, DATE',
#    'the Ikoyi High Court, ORG',
#    'Lagos, LOC'],
#   '36': ['Abia, LOC'],
#   '37': ['Wilson Uwujaren, PER',
#    'Mohammed Idris, PER',
#    'December 2019, DATE',
#    'the Ikoyi High Court, ORG',
#    'Lagos, LOC'],
#   '38': ['Sun, DATE', 'Slok Nigeria Ltd, ORG', 'EFCC, ORG'],
#   '39': ['Abia, LOC', '12 years, DATE', 'more than 7.5 billion, MONEY'],
#   '40': ['FFK, PER', 'Patience Jonathan, PER', 'Churchill Okonkwo, PER'],
#   '41': ['Kalu, PER', 'Femi Fani-Kayode, PER'],
#   '42': ['several years, DATE'],
#   '43': ['first, ORDINAL', 'Nigeria, LOC'],
#   '44': ['Nigeria, LOC'],
#   '45': ['Nigeria, LOC', 'the Fourth Republic, LOC'],
#   '46': ['Muhammadu Buhari, PER'],
#   '47': ['Nigeria, LOC'],
#   '48': ['Bola Tinubu, PER', 'Patience Jonathan, PER', 'Olisa Metu, PER'],
#   '49': ['the All Progressives Congress, ORG',
#    'the Peoples Democratic Party, ORG',
#    'Abia, LOC'],
#   '50': ['Abia, LOC', 'the Fourth Republic, LOC'],
#   '51': ['APC, ORG', 'Buhari, PER', 'South-East, LOC', 'November, DATE'],
#   '52': ['APC, ORG', 'Buhari, PER'],
#   '53': ['APC, ORG', 'Buhari, PER', 'SLOK Holding, ORG'],
#   '54': ['the Niger Delta Development Commission, ORG',
#    'SLOK Holding, ORG',
#    'Uzuakoli, LOC',
#    'Ozuitem, LOC'],
#   '55': ['Orji Uzor Kalụ, PER',
#    'the Economic and Financial Crimes Commission, ORG'],
#   '56': ['APC, ORG', '2023, CARDINAL'],
#   '57': ['Nigerians, NORP'],
#   '58': ['Tinubu, PER', 'Patience Jonathan, PER', 'Olisa Metu, PER'],
#   '59': ['Buhari, PER'],
#   '60': ['Nigerians, NORP',
#    '$ 1.1 billion, MONEY',
#    'the London Central Bank, ORG',
#    'Goodluck Jonathan, PER'],
#   '61': ['$ 9.2 million, MONEY',
#    '$ 8.4 million, MONEY',
#    'Patience Jonathan, PER',
#    "Goodluck Jonathan's, PER"],
#   '62': ['EFCC, ORG'],
#   '63': ['Jonathan, PER', 'Nigerians, NORP'],
#   '64': ['EFCC, ORG', 'Tinubu, PER', 'the day, DATE', '2019, DATE'],
#   '65': ['EFCC, ORG', 'Tinubu, PER'],
#   '66': ['Fani-Kayode, PER', "Goodluck Jonathan's, PER"],
#   '68': ['every day, DATE'],
#   '70': ['Kalu, PER'],
#   '71': ['EFCC, ORG'],
#   '72': ['Kalu, PER', 'Femi Fani-Kayode, PER'],
#   '73': ['several years, DATE'],
#   '74': ['Nigeria, LOC'],
#   '76': ['Standard Chartered Bank, ORG', 'South African, NORP'],
#   '77': ['Standard Chartered, ORG',
#    'Sahara, NORP',
#    'Standard Chartered Bank of Nigeria Limited, ORG',
#    'Standard Chartered Plc, ORG',
#    'British, NORP'],
#   '78': ['Standard Chartered, ORG',
#    'Adams Oshomole, PER',
#    'All Progressives Congress, ORG',
#    'South Africa, LOC'],
#   '79': ['Oshiomhole, PER',
#    'South African, NORP',
#    'Nigerians, NORP',
#    'Nigerian, NORP',
#    'South African, NORP',
#    'Standard Chartered, ORG'],
#   '80': ['Oshiomhole, PER',
#    'Standard Chartered House, ORG',
#    'Stanbic House, ORG',
#    'South African, NORP',
#    'Nigerians, NORP'],
#   '81': ['Nigerian, NORP'],
#   '82': ['Nigerians, NORP'],
#   '83': ['Standard Chartered, ORG',
#    'Sahara, NORP',
#    'Standard Chartered Bank of Nigeria Limited, ORG',
#    'Standard Chartered Plc, ORG',
#    'British, NORP'],
#   '84': ['Standard Chartered PLC, ORG',
#    'London, LOC',
#    'Hong Kong, LOC',
#    'Mumbai, LOC'],
#   '85': ['more than 150 years, DATE',
#    'more than 90%, PERCENT',
#    'Asia, LOC',
#    'Africa, LOC',
#    'the Middle East, LOC'],
#   '89': ['Baptist High School, ORG', 'Gbodofon, ORG', 'Oshogbo, LOC'],
#   '90': ['Oladoyin Folorunsho, PER'],
#   '92': ['last Wednesday, DATE'],
#   '93': ['Wednesdays, DATE'],
#   '94': ['a month, DATE'],
#   '95': ['This past Friday, DATE'],
#   '98': ['Sowore, PER', 'Femi Falana, PER'],
#   '100': ['Abubakar Malami, PER',
#    'SAN, ORG',
#    'Omoyele Sowore, PER',
#    'Hassan Liman, PER'],
#   '101': ['SSS, ORG', 'AGF, ORG', 'DPP, ORG'],
#   '102': ['Sowore, PER', 'SSS, ORG'],
#   '103': ['February 20, 2020, DATE'],
#   '104': ['SSS, ORG', 'Sowore, PER'],
#   '105': ['AGF, ORG', 'four-hour, TIME', 'Thursday, DATE'],
#   '106': ['the Boko Haram, ORG', 'IPOB, ORG', 'IMN, ORG'],
#   '107': ['Sowore, PER', 'Abubakar Marshal, PER'],
#   '111': ['Obasanjo, PER', 'Atiku, PER'],
#   '112': ['Wole Soyinka, PER', 'Nigeria, LOC'],
#   '113': ['Obasanjo, PER', 'Atiku, PER'],
#   '114': ['Abuja, LOC', 'Wednesday, DATE', 'Obasanjo, PER'],
#   '115': ['Obasanjo, PER'],
#   '117': ['eight years, DATE',
#    'eight years, DATE',
#    'every year, DATE',
#    'one day, DATE'],
#   '118': ['Atiku Renne, PER', 'eight-year, DATE'],
#   '120': ['Obasanjo, PER', 'Atiku, PER'],
#   '121': ['2018, DATE', 'Atiku Abubakar, PER'],
#   '122': ['2019, DATE'],
#   '125': ['Jonathan, PER'],
#   '127': ['Wole Soyinka, PER'],
#   '131': ['today, DATE'],
#   '132': ['Boko Haram, ORG', 'Khashoggi, LOC'],
#   '134': ['INTERPOL, ORG'],
#   '135': ['Rotimi Amaechi, PER'],
#   '136': ['Two or three days ago, DATE'],
#   '138': ["Pius Adesanmi's, PER", 'Saturday, DATE'],
#   '139': ['February 27, 1972, DATE', 'Naija, LOC', '2015, DATE'],
#   '140': ['Prof Pius Adesanmi, PER',
#    'Nigerian, NORP',
#    'Canadian, NORP',
#    'March 10, 2019, DATE',
#    'Ethiopian Airlines, ORG'],
#   '141': ['February 27, 1972, DATE', 'Naija, LOC', '2015, DATE'],
#   '142': ['the French Institute for Research, ORG',
#    'Africa, LOC',
#    '1993 to 1997, DATE',
#    'the French Institute of South Africa, ORG',
#    'from 1998 to 2000, DATE'],
#   '143': ['2002, DATE',
#    '2005, DATE',
#    'Pennsylvania State University, ORG',
#    'United States, LOC'],
#   '144': ['2006, DATE',
#    'Carleton University, ORG',
#    'Ottawa, LOC',
#    'Canada, LOC'],
#   '145': ['the University of African Studies, ORG'],
#   '146': ['Southampton, ORG', 'nine, CARDINAL', 'Leicester City, LOC'],
#   '147': ['Champions League, ORG',
#    'Tuuzude, LOC',
#    'Saturday, DATE',
#    'League, PER'],
#   '148': ['Southampton, ORG',
#    'last Friday, DATE',
#    'the Holy Sepulcher, ORG',
#    'nine, CARDINAL',
#    'Leicester City, LOC'],
#   '149': ["Manchester United's, ORG",
#    'nine, CARDINAL',
#    'Friday, DATE',
#    'Old Trafford, ORG',
#    'March 1995, DATE'],
#   '150': ['Ralph Hassenhuttl, PER',
#    'two, CARDINAL',
#    'Manchester City, LOC',
#    'this week, DATE'],
#   '151': ['Champions League, ORG', 'Tuuzude, LOC', 'Saturday, DATE'],
#   '152': ['Southampton, ORG',
#    'last Friday, DATE',
#    'the Saints Foundation, ORG'],
#   '153': ['the Staplewood Campus, ORG', 'this weekend, DATE'],
#   '154': ['the Saints Foundation, ORG'],
#   '155': ['Wema Bank, ORG'],
#   '156': ['Green Grace Farms, ORG'],
#   '157': ['the Ikeja High Court, ORG', 'Lagos, LOC'],
#   '159': ['Lagos State, LOC', 'Zubairu Muazu, PER'],
#   '160': ['Vanguard, ORG'],
#   '161': ['The Lagos State Police, ORG',
#    'Oluwaseun Akadiri, PER',
#    'Tunde Olafimihan, PER',
#    'Olufemi Samuel, PER',
#    'the Wema House of Nigeria Plc, ORG',
#    'the International House of Prayer, ORG',
#    'Green Grace Market Nigeria Limited, ORG'],
#   '162': ['Green Grace Workers, ORG',
#    'the Ikeja High Court of, ORG',
#    'Lagos, LOC'],
#   '163': ['Oluwaseun, PER', 'Wema Nigeria Plc, ORG'],
#   '164': ['Olubimpe, PER', 'Olusola Toheebah, PER', 'Taidol, PER'],
#   '165': ['Siyanbola Olubimpe, PER',
#    'Wema House, ORG',
#    'Iderodu, LOC',
#    'Olusola Toheebah, PER',
#    'Green Grace Ltd, ORG'],
#   '166': ['Transcon Integrated Business Limited, ORG'],
#   '167': ["the Green Grace Workers', ORG", 'the Wema House, ORG'],
#   '168': ['Green Grace Farmers, ORG',
#    'Transcon IntegratedBusiness Limited, ORG',
#    'Green Grace Ltd., ORG',
#    'Green Grace, ORG'],
#   '169': ['December 12, DATE'],
#   '170': ['Politeknnic, ORG', '20 years, DATE'],
#   '171': ['Abdulmalik, PER', 'four years, DATE', '20 years, DATE'],
#   '172': ['Olanrewaju Kayode, PER', 'Ibadan, LOC', '20 years, DATE'],
#   '173': ['the Independent Corrupt Practices, ORG',
#    'ICPC, ORG',
#    'June 2006, DATE'],
#   '174': ['Joyce Abdulmalik, PER',
#    'the Federal High Court, ORG',
#    'Ibadan, LOC'],
#   '175': ['Abdulmalik, PER', 'four years, DATE', '20 years, DATE'],
#   '176': ['June 20, 2016, DATE', 'the first day, DATE'],
#   '177': ['the Department of Accountancy of Ibadan Polytechnic, ORG'],
#   '178': ['Buhari, PER', 'three, CARDINAL', 'Saudi Arabia, LOC'],
#   '179': ['the 29th of October to the 31st day, DATE'],
#   '180': ['Buhari, PER', 'What Next for a Global Business, WORK_OF_ART'],
#   '182': ['Muhammadu Buhari, PER',
#    'Nigeria, LOC',
#    'Saudi Arabia, LOC',
#    'today, DATE',
#    'third, ORDINAL',
#    'the Future Investement Initiative, ORG',
#    'the Saudi Arabia Investment Fund, ORG'],
#   '183': ['Garba Shehu, PER', 'Sunday, DATE'],
#   '184': ['the 29th of October to the 31st, DATE',
#    'Buhari, PER',
#    'the International Trade, ORG'],
#   '185': ['three-day, DATE',
#    'two, CARDINAL',
#    'Islamic Mosque, ORG',
#    'Salman bin Abdulaziz, PER',
#    'Saudi Arabia, LOC',
#    'Crown Prince Mohammed bin Salman bin Abdulaziz, PER',
#    'the House of Economy and Development and PIF, ORG'],
#   '188': ['Buhari, PER',
#    'Babagana Zulum, PER',
#    'Abubakar Bagudu, PER',
#    'Katsina State, LOC'],
#   '189': ['Foreign Affairs, ORG',
#    'Zubairu Dada, PER',
#    'Niyi Adebayo, PER',
#    'Petroleum Resources, ORG',
#    'Timipre Sylva, PER',
#    'Ibrahim Pantami, PER',
#    'Babagana Monguno, PER',
#    'National Intelligence Agency, ORG',
#    "Ahmed Rufa'i Abubakar, PER",
#    'Nigerian National Petroleum Corporation, ORG',
#    'NNPC, ORG',
#    'Mele Kolo Kyari, PER'],
#   '190': ['Riyadh, PER',
#    'Buhari, PER',
#    'Makkah, LOC',
#    'Umrah, PER',
#    'Abuja, LOC'],
#   '191': ['Buhari, PER', 'Sonala Olumhense, PER'],
#   '192': ['Buhari, PER'],
#   '195': ['Sonala Olumhense, PER'],
#   '196': ['the mid-1980s, DATE', 'Nigerian, NORP', "the 'Black Bag', ORG"],
#   '197': ['Benjamin Adekunle, PER', 'wartime, DATE'],
#   '199': ['Surulere, LOC'],
#   '204': ['one, CARDINAL', 'two weeks later, DATE'],
#   '207': ['Black Scorpion, ORG'],
#   '211': ['last week, DATE', 'Muhammadu Buahri, PER'],
#   '212': ['Buhari, PER'],
#   '213': ['Buhari, PER'],
#   '216': ['Buhari, PER'],
#   '217': ['the past four years, DATE'],
#   '219': ['Nigerians, NORP'],
#   '221': ['Buhari, PER'],
#   '222': ['Buhari, PER', 'first, ORDINAL', 'five months, DATE'],
#   '223': ['two and a half years ago, DATE', 'Buhari, PER', 'Nigeria, LOC'],
#   '224': ['the weeks, DATE', 'Buhari, PER', 'Nigeria, LOC'],
#   '227': ['Buhari, PER'],
#   '228': ['Buhari, PER', 'the All Progressives Congress, ORG'],
#   '229': ['Bola Tinubu, PER', 'Lagos, LOC', 'Adams Oshiomhole, PER'],
#   '230': ['APC, ORG', 'Benin, LOC', 'last January, DATE', 'Nigeria, LOC'],
#   '231': ['APC, ORG'],
#   '232': ['Buhari, PER',
#    'Buhari, PER',
#    'overnight, DATE',
#    'two, CARDINAL',
#    'Lagos, LOC'],
#   '234': ['Buhari, PER',
#    'millions of dollars, MONEY',
#    'Kano, LOC',
#    'Abdullahi Ganduje, PER'],
#   '235': ['Danjuma Goje, PER', 'EFCC, ORG'],
#   '236': ['APC, ORG'],
#   '237': ['Buhari, PER'],
#   '238': ['Buhari, PER'],
#   '239': ['Buhari, PER'],
#   '241': ['Buhari, PER'],
#   '242': ['Buhari, PER', "'years, DATE"],
#   '243': ['Rotimi Amaechi, PER'],
#   '244': ['Nigerian, NORP'],
#   '246': ['seven, CARDINAL', 'the last 20 years, DATE'],
#   '247': ['Aquila, PER'],
#   '248': ['Amaechi, PER',
#    '24 hours, TIME',
#    'Buhari, PER',
#    'APC, ORG',
#    'one million, CARDINAL',
#    'Nigerians, NORP',
#    'ten years, DATE'],
#   '251': ['British, NORP'],
#   '253': ['Nigeria, LOC'],
#   '254': ['Nigerian, NORP'],
#   '255': ['PDP, ORG'],
#   '257': ['DSS Prosecution of Court Attacks, ORG', 'Nigerian Parliament, ORG'],
#   '258': ['Nigerian, NORP'],
#   '259': ['Nigerian, NORP',
#    'the Federal High Court, ORG',
#    'last Friday, DATE'],
#   '260': ['Bichi, PER', 'DSS, ORG'],
#   '261': ['Yusuf Bichi, PER'],
#   '262': ['DSS, ORG'],
#   '263': ['DSS, ORG'],
#   '264': ["Sade Adu's, PER"],
#   '265': ['these six months, DATE'],
#   '267': ['British, NORP', 'Sado Adu, PER', 'Isaac, PER'],
#   '268': ['Instagram, ORG',
#    'Thursday, DATE',
#    'Izaak, ORG',
#    'Bob Morgan, PER',
#    'Adu, PER'],
#   '271': ['these six months, DATE'],
#   '274': ['2016, DATE', 'Isaac, PER', 'the International Day, EVENT'],
#   '277': ['Tanzanian, NORP', 'John Magufuli, PER'],
#   '278': ['Magufuli, LOC', 'Nigeria, LOC', 'China, LOC'],
#   '279': ['China, LOC'],
#   '281': ['Aljazeera, ORG',
#    '2015, DATE',
#    'Magufuli, LOC',
#    '6 to 7 percent, PERCENT'],
#   '284': ['Nigeria, LOC', 'the Jonannesburg Stock Exchange, ORG', 'MTN, ORG'],
#   '285': ['Mergence Investment Managers, ORG',
#    'Cape Town, LOC',
#    'West Africa, LOC',
#    'Nolwandle Mthombeni, LOC',
#    'West African, NORP',
#    'Continental, ORG'],
#   '286': ['Nigeria, LOC', 'the Jonannesburg Stock Exchange, ORG', 'MTN, ORG'],
#   '287': ['Bloomberg West Africa, FAC'],
#   '288': ['Congo, LOC',
#    'Rwanda, LOC',
#    'Zambia, LOC',
#    'Nigeria, LOC',
#    'the World Economic Forum Summit, EVENT',
#    'West Africa, LOC'],
#   '289': ['The Government of Nigeria, ORG', 'Commerce, ORG'],
#   '290': ['more than 50, CARDINAL',
#    'African, NORP',
#    'Nigeria, LOC',
#    'West Africans, NORP',
#    'Sunday, DATE'],
#   '291': ['Nigerians, NORP'],
#   '292': ['Erasmus Ikhide, PER'],
#   '294': ['Nigeria, LOC'],
#   '297': ['DSS, ORG'],
#   '298': ['Peter AFunanya, PER'],
#   '300': ['DSS, ORG'],
#   '302': ['Boko Haram, ORG'],
#   '303': ['Peter Afunanya, PER',
#    'DSS, ORG',
#    'the Federal High Court, ORG',
#    'Abuja, LOC',
#    'Friday, DATE',
#    'DSS, ORG'],
#   '305': ['DSS, ORG', 'Omoyele Sowore, PER', 'less than 24 hours, DATE'],
#   '306': ['Afunanya, PER', 'DSS, ORG', 'Bezarre, LOC'],
#   '307': ['Afunanya, PER'],
#   '309': ['DSS, ORG', 'every day, DATE'],
#   '310': ['DSS, ORG'],
#   '311': ['the House of Representatives, ORG', 'DSS, ORG', 'Nigerians, NORP'],
#   '312': ['DSS, ORG'],
#   '313': ['Nigerians, NORP', 'one day, DATE', 'DSS, ORG', 'Nigerians, NORP'],
#   '316': ['Simi, LOC', 'Victor Uwaifo, PER', 'Joromi, PER'],
#   '317': ['$ 50 million, MONEY', 'Joromi, PER', 'one, CARDINAL'],
#   '318': ['Joromi, PER', 'first, ORDINAL', 'Uwaifo, PER', '1979, DATE'],
#   '319': ['Court, ORG', 'The Consequences of the Fall of Democracy, ORG'],
#   '320': ['several years ago, DATE', 'just a few months ago, DATE'],
#   '322': ['Omoyele Sowore, PER'],
#   '323': ['BBC, ORG'],
#   '324': ['the African Democratic Congress, ORG',
#    'Ralph Nwosu, PER',
#    'Omoyele Sowore, PER'],
#   '325': ['the State Department of Justice, ORG',
#    'the Federal High Court, ORG',
#    'last Friday, DATE',
#    'less than 24 hours, DATE'],
#   '326': ['Nigerian, NORP'],
#   '327': ['PUNCH, ORG', 'Nwosu, PER'],
#   '328': ['many years, DATE', 'just a few months ago, DATE'],
#   '331': ['Tuesday, DATE', 'Banky-W described Nigeria, ORG'],
#   '332': ['Omoyele Sowore, PER'],
#   '333': ['Nigeria, LOC'],
#   '336': ['Sowore, PER'],
#   '337': ['Nigerian, NORP'],
#   '339': ['Sowore, PER', 'these bad days, DATE', 'Nigeria, LOC'],
#   '341': ["Sowore's Foundation for Free Literacy, ORG", 'DSS, ORG'],
#   '342': ['Ondo State, LOC',
#    'Sahara Protestant, PER',
#    'Omoyele Sowore, PER',
#    'the State Department, ORG'],
#   '343': ["the Kiribo Students' Union, ORG", 'Sowore, PER', 'Nigerian, NORP'],
#   '344': ['Idepe, LOC',
#    'Okitipupa, PER',
#    'Sowore, PER',
#    'many years to date, DATE'],
#   '345': ['Olawale Bakare, PER',
#    'Amnesty International, ORG',
#    'one, CARDINAL',
#    'Africans, NORP'],
#   '346': ['Samuel Irinyemi, PER', 'Sowore, PER'],
#   '347': ['Muhammadu Buhari, PER', 'Sowore, PER'],
#   '348': ['Omoyele Sowore Foundation, ORG', 'Ondo State, LOC'],
#   '349': ['DSS, ORG'],
#   '352': ['almost five years, DATE'],
#   '357': ['Nigerian, NORP', 'Omoyele Sowore, PER', 'two, CARDINAL'],
#   '358': ['the Federal High Court, ORG',
#    'Abuja, LOC',
#    'less than 24 hours, DATE',
#    '125 days, DATE'],
#   '359': ['Buhari, PER', 'Government Are International Criticism, ORG'],
#   '360': ['Muhammadu Buhari, PER'],
#   '362': ['Buhari, PER', 'Friday, DATE', 'seventh, ORDINAL'],
#   '363': ['Sowore, PER'],
#   '364': ['ISWAP, ORG'],
#   '365': ['2018, DATE'],
#   '366': ['2018, DATE', '70%, PERCENT'],
#   '367': ['ISWAP, ORG', '14, CARDINAL', '2018, DATE'],
#   '368': ['2018, DATE', '2014, DATE'],
#   '369': ['the end of 2015, DATE',
#    '50 per cent, MONEY',
#    '2016, DATE',
#    '2017, DATE',
#    '2018, DATE'],
#   '370': ['just a few days, DATE',
#    '2018, DATE',
#    'Nigerian, NORP',
#    'Maiduguri, LOC',
#    'Borno, LOC'],
#   '371': ['Kashim Shettima, PER'],
#   '372': ['the Government House, ORG', 'Maiduguri, LOC'],
#   '373': ['Nigerian, NORP',
#    'Islamic States West Africa Province, ORG',
#    'Boko Haram, ORG'],
#   '374': ['two weeks, DATE', 'Nigerian, NORP'],
#   '375': ['the Nigerian Army, ORG'],
#   '377': ['The International Atomic Energy Agency, ORG',
#    'IAEA, ORG',
#    'Lake Chad Basin, LOC'],
#   '380': ['the International Military Task Force Base, ORG',
#    'the Multinational Joint Task Force, ORG',
#    'Baga, LOC',
#    'Maiduguri, LOC',
#    'ISWAP, ORG'],
#   '382': ['AFP, ORG', 'the North East, LOC', 'Nigerian, NORP', '2018, DATE'],
#   '383': ["Chad Basin's, LOC"],
#   '384': ['Cameroon, LOC', 'Chad, LOC', 'Niger, LOC', 'Nigeria, LOC'],
#   '385': ['ISWAP, ORG'],
#   '386': ['the Northern and Central Borno, ORG', 'Nigerian, NORP'],
#   '387': ['several years, DATE'],
#   '388': ['2018, DATE'],
#   '389': ['all year 2018, DATE', 'ISWAP, ORG'],
#   '390': ['ISWAP, ORG'],
#   '392': ['the Boko Haram / ISWAP, ORG', 'Nigeria, LOC', '2014, DATE'],
#   '393': ['ISWAP, ORG'],
#   '396': ['Lake Chad, LOC'],
#   '397': ['Maiduguri, LOC',
#    'Kinchandi, LOC',
#    'the Niger Republic, LOC',
#    'Kusiri, LOC',
#    'Cameroon, LOC'],
#   '398': ['Nigerian, NORP', 'Kusiri, LOC', 'Adamawa, LOC'],
#   '399': ['Kinchandi, LOC', 'Niger Republic, LOC'],
#   '400': ['Hadeja, LOC', 'the Niger Republic, LOC'],
#   '402': ['ISWAP, ORG'],
#   '404': ['Nigerian, NORP'],
#   '406': ['2018, DATE'],
#   '407': ['2018, DATE', '70%, PERCENT'],
#   '408': ['20, CARDINAL', 'ISWAP, ORG', '14, CARDINAL', '2018, DATE'],
#   '409': ['2018, DATE', '2014, DATE'],
#   '410': ['the end of 2015, DATE',
#    '50 per cent, MONEY',
#    '2016, DATE',
#    '2017, DATE',
#    '2018, DATE'],
#   '412': ['Mount Borno, LOC',
#    'three, CARDINAL',
#    'the Niger Republic, LOC',
#    'Chad, LOC',
#    'Cameroon, LOC'],
#   '413': ['ISWAP, ORG'],
#   '414': ['Central Borno, ORG',
#    'eight, CARDINAL',
#    'ISWAP, ORG',
#    'Boko Haram, ORG'],
#   '415': ['South Borno, LOC',
#    'nine, CARDINAL',
#    'Gwoza, ORG',
#    'Damboa, PER',
#    'Chibok, LOC'],
#   '416': ['about 45 days, DATE'],
#   '417': ['ISWAP, ORG', 'Baga, LOC'],
#   '418': ['ISWAP, ORG', 'Baga, LOC'],
#   '420': ['ISWAP, ORG'],
#   '422': ['ISWAP, ORG', 'Baga, LOC'],
#   '425': ['two days, DATE', 'Baga, LOC', 'ISWAP, ORG', 'Chad, LOC'],
#   '426': ['ISWAP, ORG', 'Nigerian, NORP', 'another day, DATE'],
#   '428': ['Jos, Plateau state, LOC', 'more than a dozen, CARDINAL'],
#   '432': ['Boko Haram, ORG'],
#   '435': ['Ibrahim Idris, PER',
#    'Premium TImes, ORG',
#    'December 28, 2018, DATE'],
#   '436': ['several months, DATE',
#    'one, CARDINAL',
#    'the Special Task Force, ORG',
#    'STF, ORG',
#    'Jos., LOC'],
#   '442': ['Nigerians, NORP', 'Nigeria, LOC'],
#   '444': ['2018, DATE'],
#   '445': ['the Niger Republic, LOC',
#    'Yobe, LOC',
#    'Adamawa, LOC',
#    'West Borno, LOC'],
#   '446': ['a year, DATE',
#    '2018, DATE',
#    '2013, DATE',
#    '2014, DATE',
#    'Maiduguri, LOC'],
#   '447': ['ISWAP, ORG'],
#   '448': ['Monguno, LOC', 'Maiduguri, LOC'],
#   '449': ['Four, CARDINAL',
#    'five, CARDINAL',
#    'Gajiram, ORG',
#    'Gajiganna, LOC',
#    'Gubio, LOC',
#    'Kareto, PER',
#    'the Niger Republic, LOC'],
#   '452': ['A few weeks ago, DATE',
#    'two, CARDINAL',
#    'Gudumbali, LOC',
#    'Kukawa, LOC'],
#   '453': ['Baga, LOC'],
#   '454': ['Maiduguri, LOC', 'Shagari, ORG', 'Maiduguri, LOC'],
#   '459': ['December 28, 2018, DATE',
#    'the Defense and Foreign Affairs Committee of the International Defense Strategic Studies Association, ORG',
#    'the United States, LOC',
#    'North, LOC',
#    'Eastern, NORP',
#    'Nigeria, LOC',
#    'Buhari, PER'],
#   '460': ['Washington, LOC',
#    "Muhammadu Buhari's, PER",
#    'Nigeria, LOC',
#    'Boko Haram, ORG'],
#   '461': ['Nigerian, NORP', 'billions of dollars, MONEY'],
#   '462': ['Lake Chad, LOC', 'ISWAP, ORG'],
#   '464': ['ISWAP, ORG', 'only one, CARDINAL'],
#   '465': ['Kano, LOC'],
#   '466': ['Nigerian, NORP'],
#   '470': ['the International Atomic Energy Agency, ORG', 'IAEA, ORG'],
#   '471': ['Nigerian, NORP',
#    'Global Terrorism Index in, WORK_OF_ART',
#    '2018, DATE',
#    'Nigeria, LOC',
#    'third, ORDINAL'],
#   '472': ['Nigeria, LOC',
#    'Iraq, LOC',
#    'Afghanistan, LOC',
#    'Syria, LOC',
#    'Pakistan, LOC'],
#   '473': ['16 per cent, MONEY', '2017, DATE', 'last year, DATE'],
#   '474': ['the World Economic Forum, ORG',
#    'two-year, DATE',
#    'Nigeria, LOC',
#    'one, CARDINAL'],
#   '475': ['Nigerian, NORP', 'Boko Haram, ORG', 'first, ORDINAL'],
#   '476': ['Ekiti, LOC'],
#   '478': ['three, CARDINAL', 'Iworoko-Ekiti, LOC', 'Ekiti State, LOC'],
#   '482': ['the Ekiti State Police, ORG'],
#   '483': ['SSS, ORG', 'Stanley Imhanruor, PER'],
#   '484': ['SSS, ORG'],
#   '485': ['Omoyele Sowore, PER', 'Olawale Bakare, PER'],
#   '486': ['SSS, ORG'],
#   '487': ['Sowore, PER', 'Sowore, PER', 'SSS, ORG'],
#   '490': ['Sowore, PER', 'SSS, ORG', 'Sowore, PER'],
#   '494': ['Nigeria, LOC'],
#   '496': ['MTN, ORG', 'Nigerians, NORP'],
#   '497': ['Rotimi Sankore, PER', 'West Africa, LOC'],
#   '498': ['Nigerians, NORP'],
#   '499': ['Nigerians, NORP', 'Nigerian, NORP'],
#   '500': ['MTN, ORG', 'Nigerians, NORP'],
#   '501': ['West Africans, NORP', 'Nigerians, NORP'],
#   '508': ['Sudan, LOC', 'Al-Bashir, PER', 'two years, DATE'],
#   '509': ['Sudanese, NORP', 'the age of 70, DATE', 'BBC, ORG'],
#   '510': ['Sudan, LOC', 'Omar al-Bashir, PER', 'two years, DATE'],
#   '511': ['Sudanese, NORP', 'the age of 70, DATE', 'BBC, ORG'],
#   '512': ['Bashir, PER', '1989, DATE', 'April, DATE'],
#   '515': ['Bashir, PER', 'Darfur, LOC'],
#   '516': ['The Super Eagles, ORG', 'four, CARDINAL'],
#   '517': ['1,493, CARDINAL', '1481, DATE'],
#   '518': ['The Nigerian Super Eagles, ORG',
#    'four, CARDINAL',
#    'November, DATE'],
#   '519': ['the International Football Confederation, ORG',
#    'Nigeria, LOC',
#    '1,493, CARDINAL',
#    '481,000, CARDINAL',
#    'October, DATE'],
#   '520': ['Eagles, ORG',
#    'third, ORDINAL',
#    'Senegal, LOC',
#    'Tunisia, LOC',
#    '27th, ORDINAL',
#    '555,065, CARDINAL'],
#   '521': ['2, CARDINAL',
#    'Benin Republic, PER',
#    '4, CARDINAL',
#    'Lesotho, LOC',
#    'the Africa Cup of Nations, EVENT'],
#   '522': ['Olamilekan, PER',
#    '11-year-old, DATE',
#    'Macron, PER',
#    'Mide Ayeni, PER'],
#   '523': ['Olemilekan, PER'],
#   '524': ['six years old, DATE'],
#   '530': ['First, ORDINAL', "the next 'twenty years', DATE"],
#   '531': ['This afternoon, DATE',
#    'Olamilekan, PER',
#    '12-year-old, DATE',
#    'French, NORP',
#    'less than two hours, TIME'],
#   '533': ['the African Idol, ORG',
#    'French, NORP',
#    'yesterday, DATE',
#    'Macron, PER'],
#   '535': ['Olamilekan, PER'],
#   '540': ['BBC, ORG'],
#   '542': ['11 years old, DATE'],
#   '544': ['Second, ORDINAL', 'Olamilekan, PER'],
#   '548': ['Olemilekan, PER'],
#   '550': ['six years old, DATE'],
#   '554': ['Harvard, ORG'],
#   '555': ['the holidays, DATE'],
#   '556': ['Onatarachi, PER'],
#   '560': ['Olajumoke, PER'],
#   '562': ['Olamilekan, PER'],
#   '563': ['Nigeria, LOC', 'Olamilekan, PER'],
#   '566': ['BBC Africa, ORG',
#    'the BBC World Service, ORG',
#    'Aljazeera, ORG',
#    'BBC, ORG'],
#   '576': ['Ronaldo, PER', 'Serana Williams, PER'],
#   '580': ['Olamilekan, PER'],
#   '581': ['Michelangelo, PER', 'Tosin, LOC'],
#   '586': ['Michelangelo, PER'],
#   '590': ['million, CARDINAL', 'twenty years, DATE'],
#   '591': ['Mide Ayeni, PER',
#    'Pearl Recycling, PER',
#    'Nigeria, LOC',
#    "the US Department of Women's Education, ORG"],
#   '592': ['Teflon and Nine Lives, ORG', 'Wumi Akintide, PER'],
#   '593': ['nine, CARDINAL',
#    'Making America Great Again, WORK_OF_ART',
#    'the United States, LOC',
#    'second, ORDINAL'],
#   '595': ['Teflon, ORG', 'nine, CARDINAL', 'Donald J. Trump, PER'],
#   '596': ['Barack Obama, PER',
#    'two, CARDINAL',
#    'eight years, DATE',
#    'the White House, LOC',
#    'nine-year-old, DATE'],
#   '599': ['the United States of America, LOC'],
#   '600': ['White House, ORG'],
#   '601': ['the White House, LOC', 'Hillary, PER', 'the United States, LOC'],
#   '602': ['Bichi, PER', 'DSS, ORG'],
#   '603': ['Yusuf Bichi, PER'],
#   '604': ['DSS, ORG'],
#   '605': ['DSS, ORG'],
#   '606': ["Sade Adu's, PER"],
#   '607': ['these six months, DATE'],
#   '609': ['British, NORP', 'Sado Adu, PER', 'Isaac, PER'],
#   '610': ['Instagram, ORG',
#    'Thursday, DATE',
#    'Izaak, ORG',
#    'Bob Morgan, PER',
#    'Adu, PER'],
#   '613': ['these six months, DATE', 'Mum, PER'],
#   '617': ['2016, DATE',
#    'Isaac, PER',
#    'the International Day, EVENT',
#    'Exile, ORG'],
#   '620': ['Tanzanian, NORP', 'John Magufuli, PER'],
#   '621': ['Magufuli, LOC', 'Nigeria, LOC', 'China, LOC', 'China, LOC'],
#   '623': ['Aljazeera, ORG',
#    '2015, DATE',
#    'Magufuli, LOC',
#    '6 to 7 percent, PERCENT'],
#   '626': ['Nigeria, LOC', 'the Jonannesburg Stock Exchange, ORG', 'MTN, ORG'],
#   '627': ['Mergence Investment Managers, ORG',
#    'Cape Town, LOC',
#    'West Africa, LOC',
#    'Nolwandle Mthombeni, LOC',
#    'West African, NORP',
#    'Continental, ORG'],
#   '628': ['Nigeria, LOC', 'the Jonannesburg Stock Exchange, ORG', 'MTN, ORG'],
#   '629': ['Bloomberg West Africa, FAC'],
#   '630': ['Congo, LOC',
#    'Rwanda, LOC',
#    'Zambia, LOC',
#    'Nigeria, LOC',
#    'the World Economic Forum Summit, EVENT',
#    'West Africa, LOC'],
#   '631': ['The Government of Nigeria, ORG', 'Commerce, ORG'],
#   '632': ['more than 50, CARDINAL',
#    'African, NORP',
#    'Nigeria, LOC',
#    'West Africans, NORP',
#    'Sunday, DATE'],
#   '633': ['Nigerians, NORP'],
#   '634': ['Erasmus Ikhide, PER'],
#   '636': ['Legislature, ORG', 'Nigeria, LOC'],
#   '639': ['DSS, ORG'],
#   '640': ['Peter AFunanya, PER'],
#   '642': ['DSS, ORG'],
#   '644': ['Boko Haram, ORG'],
#   '645': ['Peter Afunanya, PER',
#    'DSS, ORG',
#    'the Federal High Court, ORG',
#    'Abuja, LOC',
#    'Friday, DATE',
#    'DSS, ORG'],
#   '647': ['DSS, ORG', 'Omoyele Sowore, PER', 'less than 24 hours, DATE'],
#   '648': ['Afunanya, PER', 'DSS, ORG', 'Bezarre, LOC'],
#   '649': ['Afunanya, PER'],
#   '651': ['DSS, ORG', 'every day, DATE'],
#   '652': ['DSS, ORG', 'Legislature, ORG'],
#   '653': ['the House of Representatives, ORG', 'DSS, ORG', 'Nigerians, NORP'],
#   '654': ['DSS, ORG'],
#   '655': ['Nigerians, NORP', 'one day, DATE', 'DSS, ORG', 'Nigerians, NORP'],
#   '658': ['Simi, LOC', 'Victor Uwaifo, PER', 'Joromi, PER'],
#   '659': ['$ 50 million, MONEY', 'Joromi, PER', 'one, CARDINAL'],
#   '660': ['Joromi, PER', 'first, ORDINAL', 'Uwaifo, PER', '1979, DATE'],
#   '661': ['Court, ORG', 'several years ago, DATE', 'a few months ago, DATE'],
#   '663': ['Omoyele Sowore, PER'],
#   '664': ['BBC, ORG'],
#   '665': ['the African Democratic Congress, ORG',
#    'Ralph Nwosu, PER',
#    'Omoyele Sowore, PER'],
#   '666': ['the State Department of Justice, ORG',
#    'the Federal High Court, ORG',
#    'last Friday, DATE',
#    'less than 24 hours, DATE'],
#   '667': ['Nigerian, NORP'],
#   '668': ['PUNCH, ORG', 'Nwosu, PER'],
#   '669': ['many years, DATE', 'just a few months ago, DATE'],
#   '671': ['Tuesday, DATE', 'Banky-W described Nigeria, ORG'],
#   '672': ['Omoyele Sowore, PER'],
#   '673': ['Nigeria, LOC'],
#   '676': ['Sowore, PER'],
#   '677': ['Nigerian, NORP'],
#   '678': ['God, PER'],
#   '679': ['Sowore, PER', 'these bad days, DATE', 'Nigeria, LOC'],
#   '681': ["Sowore's Foundation for Free Literacy, ORG", 'DSS, ORG'],
#   '682': ['Ondo State, LOC',
#    'Sahara Protestant, PER',
#    'Omoyele Sowore, PER',
#    'the State Department, ORG'],
#   '683': ["the Kiribo Students' Union, ORG", 'Sowore, PER', 'Nigerian, NORP'],
#   '684': ['Idepe, LOC',
#    'Okitipupa, PER',
#    'Sowore, PER',
#    'many years to date, DATE'],
#   '685': ['Olawale Bakare, PER',
#    'Amnesty International, ORG',
#    'one, CARDINAL',
#    'Africans, NORP'],
#   '686': ['Samuel Irinyemi, PER', 'the Sahara Protesters, LOC', 'Sowore, PER'],
#   '687': ['Muhammadu Buhari, PER', 'Sowore, PER'],
#   '688': ['Omoyele Sowore Foundation, ORG', 'Ondo State, LOC'],
#   '689': ['DSS, ORG'],
#   '692': ['almost five years, DATE'],
#   '697': ['Nigerian, NORP', 'Omoyele Sowore, PER', 'two, CARDINAL'],
#   '698': ['the Federal High Court, ORG',
#    'Abuja, LOC',
#    'less than 24 hours, DATE',
#    '125 days, DATE'],
#   '699': ['Attacks, PRODUCT',
#    'Refusal, ORG',
#    'Buhari, PER',
#    'Government Are International Criticism, ORG'],
#   '700': ['Muhammadu Buhari, PER'],
#   '701': ['Winner Criticizes, PER', 'Opposition Opponents, ORG'],
#   '702': ['Buhari, PER', 'Friday, DATE', 'seventh, ORDINAL'],
#   '703': ['Sowore, PER'],
#   '704': ['ISWAP, ORG'],
#   '705': ['2018, DATE'],
#   '706': ['2018, DATE', '70%, PERCENT'],
#   '707': ['20, CARDINAL', 'ISWAP, ORG', '14, CARDINAL', '2018, DATE'],
#   '708': ['2018, DATE', '2014, DATE'],
#   '709': ['the end of 2015, DATE',
#    '50 per cent, MONEY',
#    '2016, DATE',
#    '2017, DATE',
#    '2018, DATE'],
#   '710': ['just a few days, DATE',
#    '2018, DATE',
#    'Nigerian, NORP',
#    'Maiduguri, LOC',
#    'Borno, LOC'],
#   '711': ['Kashim Shettima, PER'],
#   '712': ['the Government House, ORG', 'Maiduguri, LOC'],
#   '713': ['Nigerian, NORP',
#    'Islamic States West Africa Province, ORG',
#    'Boko Haram, ORG'],
#   '714': ['two weeks, DATE', 'Nigerian, NORP'],
#   '715': ['20, CARDINAL', 'the Nigerian Army, ORG', '14, CARDINAL'],
#   '717': ['The International Atomic Energy Agency, ORG',
#    'IAEA, ORG',
#    'Lake Chad Basin, LOC'],
#   '721': ['the International Military Task Force Base, ORG',
#    'the Multinational Joint Task Force, ORG',
#    'Baga, LOC',
#    'Maiduguri, LOC',
#    'ISWAP, ORG'],
#   '723': ['AFP, ORG', 'the North East, LOC', 'Nigerian, NORP', '2018, DATE'],
#   '724': ["Chad Basin's, LOC"],
#   '725': ['English, LANGUAGE',
#    'French, LANGUAGE',
#    'Cameroon, LOC',
#    'Chad, LOC',
#    'Niger, LOC',
#    'Nigeria, LOC'],
#   '726': ['ISWAP, ORG'],
#   '727': ['the Northern and Central Borno, ORG'],
#   '728': ['Nigerian, NORP'],
#   '729': ['several years, DATE'],
#   '730': ['2018, DATE'],
#   '731': ['all year 2018, DATE'],
#   '732': ['ISWAP, ORG'],
#   '733': ['ISWAP, ORG'],
#   '735': ['the Boko Haram / ISWAP, ORG', 'Nigeria, LOC', '2014, DATE'],
#   '737': ['ISWAP, ORG'],
#   '739': ['Lake Chad, LOC'],
#   '740': ['Maiduguri, LOC'],
#   '741': ['Kinchandi, LOC',
#    'the Niger Republic, LOC',
#    'Kusiri, LOC',
#    'Cameroon, LOC'],
#   '742': ['Nigerian, NORP',
#    'Kusiri, LOC',
#    'Adamawa, LOC',
#    'Kinchandi, LOC',
#    'Niger Republic, LOC'],
#   '743': ['Hadeja, LOC', 'the Niger Republic, LOC'],
#   '745': ['ISWAP, ORG'],
#   '747': ['Nigerian, NORP'],
#   '749': ['2018, DATE'],
#   '750': ['2018, DATE', '70%, PERCENT'],
#   '751': ['20, CARDINAL', 'ISWAP, ORG', '14, CARDINAL', '2018, DATE'],
#   '752': ['2018, DATE', '2014, DATE'],
#   '753': ['the end of 2015, DATE',
#    '50 per cent, MONEY',
#    '2016, DATE',
#    '2017, DATE',
#    '2018, DATE'],
#   '754': ['Mount Borno, LOC',
#    'three, CARDINAL',
#    'the Niger Republic, LOC',
#    'Chad, LOC',
#    'Cameroon, LOC'],
#   '755': ['ISWAP, ORG'],
#   '756': ['Central Borno, ORG',
#    'eight, CARDINAL',
#    'ISWAP, ORG',
#    'Boko Haram, ORG'],
#   '757': ['South Borno, LOC',
#    'nine, CARDINAL',
#    'Gwoza, ORG',
#    'Damboa, PER',
#    'Chibok, LOC'],
#   '758': ['about 45 days, DATE'],
#   '759': ['ISWAP, ORG', 'Baga, LOC'],
#   '760': ['ISWAP, ORG', 'Baga, LOC'],
#   '761': ['ISWAP, ORG'],
#   '763': ['ISWAP, ORG', 'Baga, LOC'],
#   '766': ['two days, DATE', 'Baga, LOC'],
#   '767': ['ISWAP, ORG', 'Chad, LOC'],
#   '768': ['ISWAP, ORG', 'Nigerian, NORP'],
#   '769': ['another day, DATE'],
#   '771': ['Jos, Plateau state, LOC', 'more than a dozen, CARDINAL'],
#   '774': ['Boko Haram, ORG'],
#   '777': ['Ibrahim Idris, PER',
#    'Premium TImes, ORG',
#    'December 28, 2018, DATE'],
#   '778': ['several months, DATE',
#    'one, CARDINAL',
#    'the Special Task Force, ORG',
#    'STF, ORG',
#    'Jos, LOC'],
#   '783': ['Nigerians, NORP', 'Nigeria, LOC'],
#   '785': ['2018, DATE'],
#   '786': ['the Niger Republic, LOC',
#    'Yobe, LOC',
#    'Adamawa, LOC',
#    'West Borno, LOC'],
#   '787': ['a year, DATE',
#    '2018, DATE',
#    '2013, DATE',
#    '2014, DATE',
#    'Maiduguri, LOC'],
#   '788': ['ISWAP, ORG'],
#   '789': ['Monguno, LOC', 'Maiduguri, LOC'],
#   '790': ['Four, CARDINAL',
#    'five, CARDINAL',
#    'Gajiram, ORG',
#    'Gajiganna, LOC',
#    'Gubio, LOC',
#    'Kareto, PER',
#    'the Niger Republic, LOC'],
#   '793': ['A few weeks ago, DATE',
#    'two, CARDINAL',
#    'Gudumbali, LOC',
#    'Kukawa, LOC'],
#   '794': ['Baga, LOC'],
#   '795': ['Maiduguri, LOC', 'Shagari, ORG', 'Maiduguri, LOC'],
#   '800': ['December 28, 2018, DATE',
#    'the Defense and Foreign Affairs Committee of the International Defense Strategic Studies Association, ORG',
#    'the United States, LOC',
#    'Nigeria, LOC',
#    'Buhari, PER'],
#   '801': ['Washington, LOC',
#    "Muhammadu Buhari's, PER",
#    'Nigeria, LOC',
#    'Boko Haram, ORG'],
#   '802': ['Nigerian, NORP', 'billions of dollars, MONEY'],
#   '803': ['Lake Chad, LOC', 'ISWAP, ORG'],
#   '805': ['ISWAP, ORG', 'only one, CARDINAL'],
#   '806': ['Kano, LOC'],
#   '807': ['Nigerian, NORP'],
#   '810': ['the International Atomic Energy Agency, ORG', 'IAEA, ORG'],
#   '811': ['Nigerian, NORP',
#    'Global Terrorism Index in, WORK_OF_ART',
#    '2018, DATE',
#    'Nigeria, LOC',
#    'third, ORDINAL'],
#   '812': ['Nigeria, LOC',
#    'Iraq, LOC',
#    'Afghanistan, LOC',
#    'Syria, LOC',
#    'Pakistan, LOC'],
#   '813': ['16 per cent, MONEY', '2017, DATE', 'last year, DATE'],
#   '814': ['the World Economic Forum, ORG',
#    'two-year, DATE',
#    'Nigeria, LOC',
#    'one, CARDINAL'],
#   '815': ['Nigerian, NORP', 'Boko Haram, ORG', 'first, ORDINAL'],
#   '816': ['Ekiti, LOC'],
#   '818': ['three, CARDINAL', 'Iworoko-Ekiti, LOC', 'Ekiti State, LOC'],
#   '822': ['the Ekiti State Police, ORG'],
#   '823': ['SSS, ORG', 'Stanley Imhanruor, PER'],
#   '824': ['SSS, ORG'],
#   '825': ['Omoyele Sowore, PER', 'Olawale Bakare, PER'],
#   '826': ['SSS, ORG'],
#   '827': ['Sowore, PER', 'Sowore, PER', 'SSS, ORG'],
#   '830': ['Sowore, PER', 'SSS, ORG', 'Sowore, PER'],
#   '834': ['Nigeria, LOC'],
#   '836': ['MTN, ORG', 'Nigerians, NORP'],
#   '837': ['Rotimi Sankore, PER', 'West Africa, LOC'],
#   '840': ['MTN, ORG', 'Nigerians, NORP'],
#   '841': ['West Africans, NORP', 'Nigerians, NORP'],
#   '847': ['Sudan, LOC', 'Al-Bashir, PER', 'two years, DATE'],
#   '848': ['Sudanese, NORP', 'the age of 70, DATE', 'BBC, ORG'],
#   '849': ['Sudan, LOC', 'Omar al-Bashir, PER', 'two years, DATE'],
#   '850': ['Sudanese, NORP', 'the age of 70, DATE', 'BBC, ORG'],
#   '851': ['Bashir, PER', '1989, DATE', 'April, DATE'],
#   '854': ['Bashir, PER', 'Darfur, LOC'],
#   '855': ['The Super Eagles, ORG', 'four, CARDINAL'],
#   '856': ['1,493, CARDINAL', '1481, DATE'],
#   '857': ['The Nigerian Super Eagles, ORG',
#    'four, CARDINAL',
#    'November, DATE'],
#   '858': ['the International Football Confederation, ORG',
#    'Nigeria, LOC',
#    '1,493, CARDINAL',
#    '481,000, CARDINAL',
#    'October, DATE'],
#   '859': ['Eagles, ORG',
#    'third, ORDINAL',
#    'Senegal, LOC',
#    'Tunisia, LOC',
#    '27th, ORDINAL',
#    '555,065, CARDINAL'],
#   '860': ['2, CARDINAL',
#    'Benin Republic, PER',
#    '4, CARDINAL',
#    'Lesotho, LOC',
#    'the Africa Cup of Nations, EVENT'],
#   '861': ['Olamilekan, PER',
#    '11-year-old, DATE',
#    'Macron, PER',
#    'Mide Ayeni, PER'],
#   '862': ['Olemilekan, PER'],
#   '865': ['six years old, DATE'],
#   '871': ['First, ORDINAL', "the next 'twenty years', DATE"],
#   '872': ['This afternoon, DATE',
#    'Olamilekan, PER',
#    '12-year-old, DATE',
#    'French, NORP',
#    'less than two hours, TIME'],
#   '873': ['the African Idol, ORG',
#    'French, NORP',
#    'yesterday, DATE',
#    'Macron, PER'],
#   '875': ['Olamilekan, PER'],
#   '880': ['BBC, ORG'],
#   '882': ['11 years old, DATE'],
#   '884': ['Second, ORDINAL', 'Olamilekan, PER'],
#   '888': ['Olemilekan, PER'],
#   '890': ['six years old, DATE'],
#   '893': ['Harvard, ORG'],
#   '894': ['the holidays, DATE'],
#   '896': ['Onatarachi, PER'],
#   '898': ['Olajumoke, PER'],
#   '901': ['Olamilekan, PER'],
#   '902': ['Nigeria, LOC', 'Olamilekan, PER'],
#   '904': ['BBC Africa, ORG',
#    'the BBC World Service, ORG',
#    'Aljazeera, ORG',
#    'BBC, ORG'],
#   '912': ['Ronaldo, PER', 'Serana Williams, PER'],
#   '917': ['Olamilekan, PER', 'Michelangelo, PER', 'Tosin, LOC'],
#   '922': ['Michelangelo, PER'],
#   '927': ['million, CARDINAL', 'twenty years, DATE'],
#   '928': ['Mide Ayeni, PER', 'Pearl Recycling, PER', 'Nigeria, LOC'],
#   '929': ["the US Department of Women's Education, ORG"],
#   '930': ['Teflon and Nine Lives, ORG', 'Wumi Akintide, PER'],
#   '931': ['the United States, LOC', 'second, ORDINAL'],
#   '933': ['Teflon, ORG', 'nine, CARDINAL', 'Donald J. Trump, PER'],
#   '934': ['Barack Obama, PER',
#    'two, CARDINAL',
#    'eight years, DATE',
#    'the White House, LOC',
#    'nine-year-old, DATE'],
#   '937': ['the United States of America, LOC'],
#   '938': ['White House, ORG'],
#   '939': ['the White House, LOC', 'Hillary, PER', 'the United States, LOC'],
#   '941': ['Joseph Achuzie, PER', 'Biafran, PER'],
#   '942': ['Dapchi: Government, ORG', 'Boko Haram, ORG', 'Massob, ORG'],
#   '943': ['Tottenham, LOC', 'Rochadale, ORG'],
#   '944': ['Fernando Llorente, PER',
#    'Kyle Walter-Peters, PER',
#    'yesterday, DATE',
#    'FA cup, WORK_OF_ART'],
#   '945': ['Tottenham, LOC', 'FA, WORK_OF_ART'],
#   '946': ['Tottenham, LOC', 'eight, CARDINAL', 'FA cup, LAW'],
#   '947': ['Tottenham, LOC',
#    'Rochadale, ORG',
#    '6, CARDINAL',
#    'FA cup, WORK_OF_ART'],
#   '948': ['Tottenham, LOC', 'the 17th of March, DATE'],
#   '949': ['first, ORDINAL',
#    'fifth, ORDINAL',
#    'Fernando Llorente, PER',
#    'twelve minutes of the second half, TIME',
#    'Kyle Walter-Peters, PER',
#    'sixth, ORDINAL'],
#   '950': ['Rochadale, ORG'],
#   '952': ['Tottenham, LOC',
#    'Wembley, PER',
#    'the 3rd of March, DATE',
#    'League, PER',
#    'Juventus, ORG',
#    'Champions League, ORG',
#    'the 7th day of March, DATE'],
#   '954': ['first, ORDINAL', 'Plymouth, LOC', 'the 3rd day of March, DATE'],
#   '956': ['first, ORDINAL', 'England, LOC'],
#   '957': ['Champions League, ORG', 'Neymar, PER'],
#   '960': ['Ibrahim Idris, PER'],
#   '961': ['The Inspector General of Police, ORG', 'Ibrahim Idris, PER'],
#   '962': ['The Inspector General of Police, ORG',
#    'yesterday, DATE',
#    'Kaduna, LOC'],
#   '963': ['Benue, LOC'],
#   '964': ['Muhammadu Buhari, PER'],
#   '965': ['Idris, PER'],
#   '967': ['Alaba International Market, ORG'],
#   '968': ['Biafra, LOC'],
#   '969': ['Imo State, LOC'],
#   '970': ['Imo State, LOC'],
#   '971': ['Imo State, LOC'],
#   '973': ['George Weah, PER'],
#   '974': ['Timothy Weah, PER', '1992 to 1995, DATE'],
#   '975': ['Timothy Weah, PER'],
#   '976': ['Timothy Weah, PER'],
#   '977': ['Liberia, LOC', 'George Weah, PER', 'Timothy Weah, PER'],
#   '978': ['yesterday, DATE', 'Troyes, PER'],
#   '979': ['Neymar, PER',
#    'Kylian Mbappe, ORG',
#    'Maria, PER',
#    'Christopher Nkunu, PER'],
#   '980': ['Neymar, PER', 'Mbappe, ORG'],
#   '981': ['George Weah, PER', '55, CARDINAL'],
#   '982': ['George Weah, PER', '23 years ago, DATE', 'AC Milan, ORG'],
#   '983': ['PGS, ORG',
#    '10, CARDINAL',
#    '17, CARDINAL',
#    'year, DATE',
#    'French League, ORG'],
#   '984': ['Real Madrid, ORG',
#    'Tusde, NORP',
#    'second, ORDINAL',
#    'first, ORDINAL',
#    'Real Madrid, ORG'],
#   '985': ['Neymar, PER', 'this season, DATE'],
#   '987': ['Dapchi, LOC'],
#   '988': ['One, CARDINAL', 'Awada, LOC'],
#   '990': ['Charly Boy, PER', 'Nigeria, LOC'],
#   '991': ['Charles Oputa, PER', 'Charly Boy, PER', 'Nigeria, LOC'],
#   '992': ['Charly Boy, PER', 'Nigeria, LOC', 'Nigeria, LOC'],
#   '993': ['BBC Igbo, NORP', 'Nigeria, LOC'],
#   '994': ['Charly Boy, PER', 'Nigeria, LOC'],
#   '995': ['thirty five years ago, DATE', 'Nigeria, LOC', 'Charly Boy, PER'],
#   '996': ['Oscar, PER', '2018, DATE', 'Kobe Byant, PER'],
#   '997': ['American, NORP', 'Kobe Bryant, PER'],
#   '998': ['Kobe Bryant, PER', 'American, NORP'],
#   '999': ['Kobe Bryant, PER'],
#   '1000': ['Kobe Bryant, PER', 'American, NORP', 'Oscar, PER'],
#   '1002': ['Oscar, PER'],
#   '1005': ['Frances McDormand, PER', 'Three, CARDINAL', 'Missouri, LOC'],
#   '1006': ['Gary Oldman, PER', 'Darkest Hour, PRODUCT'],
#   '1007': ['Guillermo Del Toro, PER', 'the The Shape of Water, WORK_OF_ART'],
#   '1008': ['Jordan Peele, PER'],
#   '1009': ['2018, DATE'],
#   '1010': ['Hollywood, LOC'],
#   '1012': ['Black Panther, NORP', 'Walking Dead, PER'],
#   '1015': ['Daniel Kuluuya, PER'],
#   '1016': ['Daniel Kaluuya, PER', 'British, NORP'],
#   '1018': ['2012, DATE', 'Twelve Years a Slave, WORK_OF_ART'],
#   '1019': ['Jennifer Lawrence, PER'],
#   '1020': ['Jennifer Lawrence, PER', 'Oscar, PER'],
#   '1021': ['Andra Day, PER'],
#   '1022': ['Andra Day, PER', 'American, NORP'],
#   '1023': ['2018, DATE'],
#   '1024': ['Black Panther, NORP'],
#   '1025': ['Africa, LOC', 'Black Panther, NORP'],
#   '1026': ['Black Panther, NORP'],
#   '1027': ['Tom Holland, PER'],
#   '1028': ['Tom Holland, PER', "Spider Man', PER"],
#   '1029': ['Chadwick Boseman, PER'],
#   '1030': ['Chadwick Boseman, PER',
#    'Wakanda, LOC',
#    "'Black Panther', WORK_OF_ART",
#    'Oscars, ORG'],
#   '1031': ['Ashley Judd, PER'],
#   '1032': ['Ashley Judd, PER', 'Time, ORG'],
#   '1033': ['Adam Rippon, PER'],
#   '1034': ['Adam Rippon, PER', 'English, LANGUAGE', 'Fifty, CARDINAL'],
#   '1035': ['Salman Hayek, PER'],
#   '1036': ['Salman Hayek, PER'],
#   '1037': ['Darrell Britt-Gibson, PER'],
#   '1038': ['Darrell Britt-Gibson, PER', "Three Billboards', WORK_OF_ART"],
#   '1039': ['Whoopi Goldberg, PER'],
#   '1040': ["Whoopi Goldberg's, PER"],
#   '1041': ['Patrick Stewart, PER'],
#   '1042': ['Patrick Stewart, PER', 'Time, ORG'],
#   '1043': ['Sally Hawkins, PER'],
#   '1044': ['Sally Hawkins, PER',
#    'British, NORP',
#    "The Shape of Water', WORK_OF_ART"],
#   '1046': ['10 years, DATE', '13 years old, DATE'],
#   '1047': ['Meryl Streep, PER'],
#   '1048': ['Meryl Streep, PER', '21, CARDINAL'],
#   '1049': ['Margot Robbie, PER'],
#   '1050': ['Margot Robbie, PER', 'Tonya, PER'],
#   '1051': ['Tiffany Haddish, PER'],
#   '1052': ['Tiffany Haddish, PER',
#    'African, NORP',
#    'Eritrean, NORP',
#    'Ethiopian, NORP'],
#   '1054': ['Africans, NORP', 'Nigeria, LOC'],
#   '1057': ['2018, DATE', 'the 90th year, DATE', 'Hollywood, LOC'],
#   '1058': ['2018, DATE', 'BBC Igbo, NORP', 'African, NORP', 'Nigeria, LOC'],
#   '1059': ['2018, DATE', 'Africa, LOC', 'Nigeria, LOC'],
#   '1060': ['BBC, ORG', 'Nigeria, LOC', 'Hollywood, LOC', 'Hollywood, LOC'],
#   '1061': ['Nigeria, LOC', 'African, NORP', 'African, NORP'],
#   '1062': ['American, NORP', 'Kenyan, NORP', 'the year 2013, DATE'],
#   '1063': ['Few years ago, DATE', 'Nigeria, LOC', 'Africa, LOC'],
#   '1064': ['second, ORDINAL', 'one year, DATE', 'Hollywood, LOC'],
#   '1065': ['Africa Kenya, LOC', 'South Africa, LOC', 'Nigeria, LOC'],
#   '1066': ['South Africa, LOC'],
#   '1068': ['Nigeria, LOC'],
#   '1070': ['Nigerian, NORP', 'Buhari, PER'],
#   '1071': ['Nigerian, NORP', 'Buhari, PER', 'CHOGM, ORG'],
#   '1072': ['Muhammadu Buhari, PER'],
#   '1073': ['Nigerians, NORP', 'Muhammadu Buhari, PER'],
#   '1074': ['Nigeria, LOC'],
#   '1075': ['Buhari, PER', 'London, LOC', 'CHOGM, ORG', 'Nigerian, NORP'],
#   '1076': ['Nigerians, NORP'],
#   '1077': ['Three, CARDINAL', 'Buhari, PER', 'Nigerians, NORP'],
#   '1078': ['Buhari, PER'],
#   '1079': ['Nigerians, NORP'],
#   '1080': ['Buhari, PER', 'Femi Adesina, PER', 'Nigerians, NORP'],
#   '1081': ['Adesina, PER'],
#   '1083': ['Nigeria, LOC'],
#   '1086': ['Buhari, PER', '2019, DATE'],
#   '1088': ['commonwealth, ORG'],
#   '1090': ['Queen Elizabeth, PER'],
#   '1091': ['England, LOC', 'Charles, PER'],
#   '1093': ['Thursday, DATE',
#    'Britain, LOC',
#    'Charles, PER',
#    'CHOGM, ORG',
#    'Buckingham, LOC'],
#   '1094': ['CHOGM, ORG', 'one day, DATE'],
#   '1095': ['Queen, PER'],
#   '1096': ['Windsor, ORG'],
#   '1098': ['BBC, ORG', 'James Landale, PER'],
#   '1099': ['South Africa, LOC', 'Cyril Ramaphosa, PER', 'London, LOC'],
#   '1100': ['South Africa, LOC'],
#   '1102': ['Britain, LOC'],
#   '1106': ['Chimamanda, PER'],
#   '1107': ['Nigerians, NORP'],
#   '1108': ['Nigerian, NORP', 'Buhari, PER'],
#   '1111': ['Theresa, PER',
#    'Canada, LOC',
#    'Justin Trudeau, PER',
#    'Prince Charles, PER'],
#   '1112': ['CHOGM, ORG'],
#   '1113': ['CHOGM, ORG',
#    'Commonwealth of Government Meeting, ORG',
#    'English, LANGUAGE'],
#   '1114': ['twice every two years, DATE'],
#   '1116': ['the year, DATE', 'London, LOC', 'Valletta, ORG', 'Malta, LOC'],
#   '1117': ['Imo, LOC', 'Rochas, PER'],
#   '1118': ['Imo State, LOC', 'ten billion naira, MONEY'],
#   '1119': ['Rochas Okorocha, PER', 'Ogoni, PER', 'Godwin Gininwa, PER'],
#   '1120': ['Rochas Okorocha, PER', '2019, DATE'],
#   '1121': ['Imo State, LOC', 'three thousand naira, CARDINAL'],
#   '1122': ['Ebere Iwuji, PER', 'BBC Igbo, NORP'],
#   '1125': ['Imo State, LOC', 'Community Government Councils, ORG'],
#   '1126': ['Imo, LOC', 'ten billion, CARDINAL'],
#   '1127': ['Nzewuji, PER'],
#   '1128': ['monthly, DATE'],
#   '1133': ['this night, DATE', 'Buhari, PER', 'Nigeria, LOC'],
#   '1134': ['APC, ORG'],
#   '1135': ['2019, DATE', 'APC, ORG', '2019, DATE'],
#   '1137': ['1999, DATE'],
#   '1138': ['Nigerians, NORP', 'Buhari, PER', '2019, DATE'],
#   '1139': ['next week, DATE'],
#   '1140': ['Peoples Democratic Party, ORG',
#    'All Progressive Congresss, ORG',
#    'APC, ORG',
#    'Social Democratic Party, ORG',
#    'SDP, ORG',
#    'about twenty three, CARDINAL'],
#   '1141': ['Coalition for Nigeria Movement, ORG',
#    'CNM, ORG',
#    'Nigeria, LOC',
#    'Obasanjo, PER'],
#   '1142': ['Obasanjo, PER'],
#   '1143': ['2019, DATE', 'Keyamo, PER', 'Buhari, PER'],
#   '1144': ['Buhari, PER', '2019, DATE'],
#   '1145': ['the year 2015, DATE'],
#   '1146': ['Nigeria, LOC'],
#   '1147': ['One, CARDINAL', 'APC, ORG'],
#   '1151': ['sixteen years, DATE', 'APC, ORG'],
#   '1152': ['POP, ORG'],
#   '1153': ['Uche Secondus, PER'],
#   '1154': ['Nigeria, LOC', 'APC, ORG'],
#   '1156': ['three thousand naira, QUANTITY', 'Imo State, LOC'],
#   '1158': ['Nigerian, NORP', 'Buhari, PER'],
#   '1159': ["Ebube Muonso's, PER"],
#   '1162': ['Igbos, PER'],
#   '1163': ['Saturday, DATE'],
#   '1164': ['Catholic, NORP',
#    'Emmanuel Obimma, PER',
#    'Ebube Muonso, PER',
#    'Friday, DATE',
#    'Saturday, DATE',
#    'morning, DATE'],
#   '1165': ['Francis Okoye, PER',
#    'BBC, ORG',
#    '8pm, DATE',
#    'night, DATE',
#    'more than thirty, CARDINAL'],
#   '1166': ['Àgùlerì, LOC', 'Igboukwu, LOC'],
#   '1167': ['Awada, LOC'],
#   '1178': ['Nkiru Nwode, PER', 'BBC, ORG', 'three, CARDINAL'],
#   '1179': ['first, ORDINAL',
#    'Catholics, NORP',
#    'Friday, DATE',
#    'night, DATE',
#    'more than two thousand, CARDINAL'],
#   '1181': ['Obimma, PER'],
#   '1186': ['APC, ORG'],
#   '1187': ['Buhari, PER'],
#   '1188': ['Buhari, PER', '2023, CARDINAL'],
#   '1190': ['Igboukwu, LOC', 'one, CARDINAL', 'Igbo, NORP', 'Nigeria, LOC'],
#   '1191': ['Buhari, PER', '2019, DATE', '2015, DATE'],
#   '1192': ['2023, CARDINAL', 'Buhari, PER', '2019, DATE'],
#   '1193': ['APC, ORG',
#    'Amechi, PER',
#    'Boss Mustapha, PER',
#    'Voice of Nigeria, ORG',
#    'Osita Okechukwu, PER',
#    'Buhari, PER',
#    '2019, DATE'],
#   '1194': ['2019, DATE', 'Balarabe Musa, PER'],
#   '1197': ['the Sun Newspaper, ORG'],
#   '1199': ['Yoruba, LOC', 'Nigeria, LOC', 'Nigeria, LOC'],
#   '1200': ['2023, CARDINAL', 'Igbos, PER'],
#   '1201': ['Ohanaeze Ndigbo, ORG', 'Dozie Ikedife, PER'],
#   '1202': ["Sun Newspaper ', ORG"],
#   '1205': ['Biafra, LOC'],
#   '1206': ['2015, DATE',
#    'Igbos, PER',
#    'Buhari, PER',
#    '95%, PERCENT',
#    '5%, PERCENT'],
#   '1211': ['America, LOC'],
#   '1215': ['four, CARDINAL', 'Nashville, LOC', 'America, LOC'],
#   '1218': ['Travis Reinking, PER', '29 years old, DATE', 'Illinois, LOC'],
#   '1223': ['2019, DATE'],
#   '1224': ['Wole Soyinka, PER'],
#   '1225': ['The Nobel Prize, WORK_OF_ART', 'Nigeria, LOC'],
#   '1226': ['Wole Soyinka, PER', 'Nigerians, NORP'],
#   '1227': ['Wole Soyinka, PER', 'Nigerians, NORP', '2019, DATE'],
#   '1228': ['Sunday, DATE',
#    'Gani Fawehinmi, PER',
#    'Lagos, LOC',
#    'Nigeria, LOC'],
#   '1229': ['Nigeria, LOC', 'Nigerians, NORP'],
#   '1230': ['Buhari, PER', 'APC, ORG'],
#   '1231': ['Wole Soyinka, PER'],
#   '1237': ['Nigeria, LOC'],
#   '1244': ['Nigeria, LOC', 'one, CARDINAL', 'two, CARDINAL'],
#   '1245': ['Nigeria, LOC', 'today, DATE'],
#   '1246': ['Nigerians, NORP', 'America, LOC'],
#   '1247': ['America, LOC'],
#   '1248': ['Yemi Osibanjo, PER', 'Abuja, LOC'],
#   '1249': ['Yemi Osibanjo, PER'],
#   '1250': ['Nigeria, LOC',
#    'Nigeria, LOC',
#    'Washington DC, LOC',
#    'America, LOC'],
#   '1251': ['Nigeria, LOC'],
#   '1252': ['Yemi Osibanjo, PER',
#    'Kemi Adeosun, PER',
#    'Ibe Kachikwu, PER',
#    'Agriculture Audu Ogbeh, ORG',
#    'Ogbonnaya Onu, PER',
#    'Lai Mohammed, PER'],
#   '1254': ['Switzerland, LOC', 'Abacha, PER'],
#   '1255': ['Sanusi Lamido, PER', 'Kano, LOC', 'Nigeria, LOC'],
#   '1256': ['Sanusi, PER'],
#   '1257': ['Africa, LOC',
#    'Nigeria, LOC',
#    'Ghana, LOC',
#    'Ruwanda, LOC',
#    'Kenya, LOC',
#    'South Africa, LOC'],
#   '1258': ['500, MONEY',
#    'Nigeria, LOC',
#    '100, MONEY',
#    'Ghana, LOC',
#    '100, MONEY',
#    'Ruwanda, LOC',
#    '100, MONEY'],
#   '1259': ["9 o'clock, DATE", "10 o'clock, DATE"],
#   '1260': ['Nigeria, LOC'],
#   '1261': ['Sanusi, PER'],
#   '1262': ['Nigeria, LOC'],
#   '1263': ['Nigeria, LOC'],
#   '1264': ['Nigeria, LOC'],
#   '1265': ['Ruwandans, ORG', 'Paul Kagame, PER', 'Ruwanda, LOC'],
#   '1267': ['Sanusi, PER'],
#   '1269': ['Lai Mohammed, PER'],
#   '1270': ['Mohammed, PER', 'Washington DC, LOC'],
#   '1271': ['the Ministers of Agriculture, ORG', 'Labour, ORG'],
#   '1272': ['London, LOC'],
#   '1273': ['Washington DC, LOC', 'IMF, ORG'],
#   '1275': ['Lai Mohammed, PER'],
#   '1277': ['Ikeogu Oke, PER',
#    '10,000, MONEY',
#    'Nigerian Prize of Literature, WORK_OF_ART'],
#   '1281': ['BBC, ORG', 'Oke, PER', 'Igbo, NORP'],
#   '1282': ['Abacha, PER'],
#   '1283': ['Abacha, PER', 'Nigeria, LOC'],
#   '1284': ['Kemi Adeosun, PER', 'Christine Lagarde, PER', 'IMF, ORG'],
#   '1285': ['Nigerian, NORP',
#    'more than three hundred million dollars, CARDINAL',
#    'Abacha, PER',
#    'Swiss, NORP'],
#   '1286': ['Finance, ORG', 'Kemi Adeosun, PER', 'Buhari, PER'],
#   '1287': ['International Monetary Fund, ORG',
#    'Washington DC, LOC',
#    'America, LOC'],
#   '1288': ['Nigeria, LOC'],
#   '1290': ['Central Bank, ORG'],
#   '1291': ['Nigeria, LOC'],
#   '1292': ['Nigeria, LOC'],
#   '1293': ['Nigeria, LOC', 'CHOGM, ORG'],
#   '1295': ['Nigerians, NORP', 'America, LOC'],
#   '1297': ['IMF, ORG', 'Nigeria, LOC', 'more than one, CARDINAL'],
#   '1299': ['EFCC, ORG', 'Umar, PER', 'ten million, CARDINAL'],
#   '1300': ['IMF, ORG', 'Nigeria, LOC'],
#   '1301': ['Nigeria, LOC',
#    'at least five, CARDINAL',
#    'one, CARDINAL',
#    'Nigeria, LOC',
#    'one, CARDINAL',
#    'Muslim, NORP',
#    'Mecca, LOC',
#    'Saudi Arabia, LOC',
#    'one, CARDINAL',
#    'Christians, NORP',
#    'one, CARDINAL'],
#   '1302': ['Pat Utomi, PER', 'Uche, PER', 'BBC, ORG'],
#   '1305': ['Pat Utomi, PER'],
#   '1307': ['Abacha, PER'],
#   '1309': ['Uche, PER'],
#   '1311': ['Uwaleke, PER'],
#   '1317': ['Nigeria, LOC'],
#   '1319': ['today, DATE', 'today, DATE'],
#   '1320': ['this morning, DATE', 'today, DATE', 'APC, ORG'],
#   '1321': ['Uche Anichukwu, PER', 'BBC Igbo, NORP', 'EFCC, ORG', 'Abuja, LOC'],
#   '1322': ['Saraki, PER', 'this morning, DATE', 'EFCC, ORG'],
#   '1323': ['EFCC, ORG', 'English, LANGUAGE'],
#   '1324': ['Saraki, PER'],
#   '1325': ['Sam Anyanwu, PER', 'yesterday, DATE'],
#   '1327': ['This morning, DATE', 'Saraki, PER'],
#   '1328': ['Nigeria, LOC', 'Muhammadu Buhari, PER', 'APC, ORG', 'today, DATE'],
#   '1330': ['EFCC, ORG', 'Abuja, LOC'],
#   '1331': ['EFCC, ORG', 'Ekweremadu, PER'],
#   '1333': ['John Adeyi, PER'],
#   '1335': ['Makurdi, LOC',
#    'Benue, LOC',
#    'two, CARDINAL',
#    'Hartuna Idi, PER',
#    'Suleiman Gina, PER',
#    'John Adeyi, PER'],
#   '1336': ['four, CARDINAL',
#    'Saidu Abdullahi, PER',
#    'Aliyu Garba, PER',
#    'Catholic, NORP',
#    'Otukpo Diocese, ORG',
#    'Benue, LOC',
#    'Otukpo, LOC',
#    '2016, DATE'],
#   '1340': ['One, CARDINAL', 'two, CARDINAL', 'today, DATE', 'Wednesday, DATE'],
#   '1341': ['Daily Post, ORG'],
#   '1342': ['Adeyi, PER'],
#   '1345': ['APC, ORG'],
#   '1351': ['Igbuzo, LOC', 'Delta, LOC'],
#   '1373': ['that day, DATE'],
#   '1379': ['Anthony Mgbolu, PER', 'BBC Igbo, NORP'],
#   '1381': ['Africa, LOC',
#    'the University of Lagos Chiagozie Nnabuihe, PER',
#    'BBC Igbo, NORP'],
#   '1382': ['Nnabuihe, PER'],
#   '1383': ['Yoruba, LOC'],
#   '1384': ['Yorubas, ORG'],
#   '1386': ['Nnamdi Daniels, PER'],
#   '1388': ['Nnamdi Daniels, PER', 'BBC Igbo, NORP'],
#   '1392': ['The Ministry of Health, ORG', 'more than two million, CARDINAL'],
#   '1396': ['Isaac Adewole, PER'],
#   '1397': ['Nigeria, LOC'],
#   '1399': ['NAFDAC, ORG', 'Emzor, ORG'],
#   '1400': ['Adewole, PER',
#    'National Agency for Food and Drug Administration, ORG'],
#   '1401': ['May this year, DATE', 'BBC, ORG', 'Nigeria, LOC'],
#   '1405': ['2019, DATE'],
#   '1414': ['Africa, LOC',
#    'University of Lagos, ORG',
#    'Chiagozie Nnabuihe, PER',
#    'BBC Igbo, NORP'],
#   '1418': ['Nnabuihe, PER'],
#   '1423': ['today, DATE'],
#   '1429': ['Hernia, LOC'],
#   '1430': ['Nnabuihe, PER'],
#   '1437': ['Nnabuihe, PER'],
#   '1440': ['today, DATE'],
#   '1441': ['Imo State, LOC'],
#   '1444': ['Ihiala, LOC'],
#   '1447': ['Nnabuihe, PER'],
#   '1450': ['Twitter, ORG'],
#   '1452': ['Ahmed Musa, PER', "Al Nasr's, PER", 'today, DATE'],
#   '1453': ['Musa, PER', "Al Nasr's, PER"],
#   '1454': ['Ahmed Musa, PER'],
#   '1455': ['Ahmed Musa, PER'],
#   '1456': ['Musa, PER',
#    'world cup, EVENT',
#    'Leicester City, LOC',
#    'Al Nasr, ORG',
#    "Saudi Arabia's, LOC"],
#   '1457': ['Leicester City, LOC',
#    'up to seventeen million, MONEY',
#    'five hundred pounds, QUANTITY'],
#   '1458': ['the Super Eagles, ORG'],
#   '1459': ['The Super Eagles, ORG'],
#   '1460': ['World Cup 2018, EVENT', 'Nigerians, NORP', 'Ahmed Musa, PER'],
#   '1461': ['Leicester City, LOC',
#    'Moscow, LOC',
#    'the year 2016, DATE',
#    'the 2017 football season, DATE'],
#   '1462': ['the World Cup, EVENT', 'Galatasaray, PER'],
#   '1464': ['Ahmed Musa, PER'],
#   '1465': ['Babatunda Fashola, PER', 'Nigerians, NORP'],
#   '1466': ['Babatunde Fashola, PER', 'Nigeria, LOC'],
#   '1468': ['Nigerians, NORP'],
#   '1469': ['Nigeria, LOC', 'seven thousand megawatts, QUANTITY'],
#   '1470': ['Fashola, PER',
#    'Calabar, LOC',
#    'Cross River State, LOC',
#    'yesterday, DATE'],
#   '1472': ['three months, DATE'],
#   '1473': ['Fashola, PER', 'Calabar, LOC'],
#   '1474': ['2015, DATE'],
#   '1475': ['Fashola, PER', 'three, CARDINAL', 'Buhari, PER'],
#   '1476': ['Three years ago, DATE', 'Nigeria, LOC'],
#   '1477': ['Nigeria, LOC'],
#   '1479': ['5,222, CARDINAL', 'Nigeri, LOC'],
#   '1484': ['Kano, LOC'],
#   '1485': ['Four, CARDINAL', 'Port Harcourt, LOC'],
#   '1488': ['Oprah Winfrey, PER'],
#   '1491': ['summer, DATE'],
#   '1493': ['Four, CARDINAL', '12, CARDINAL', 'Thailand, LOC'],
#   '1494': ['Buhari, PER'],
#   '1496': ['Swimming, NORP'],
#   '1498': ['today, DATE'],
#   '1521': ['Nigeria, LOC'],
#   '1523': ['Lagos, LOC', 'Edgal Imohimi, PER', 'Ikorodu, LOC'],
#   '1524': ['Ogun, LOC'],
#   '1528': ['Joseph, PER'],
#   '1530': ['Ondo, LOC', 'one, CARDINAL'],
#   '1531': ['24 hours, TIME'],
#   '1533': ['Hadijat Kabir, PER',
#    'two, CARDINAL',
#    'fifteen million naira ransom, QUANTITY'],
#   '1534': ['Lagos, LOC', 'Edgal Imohimi, PER'],
#   '1535': ['Ebonyi State University, ORG', 'Nnachi Amos, PER'],
#   '1537': ['Yaba, LOC', 'Lagos State, LOC', 'Amos, PER'],
#   '1542': ['Ozubulu Church Massacre, ORG', 'One year, DATE'],
#   '1545': ['nine days, DATE'],
#   '1546': ['Ondo State Police, ORG'],
#   '1548': ['BBC, ORG'],
#   '1549': ['Ondo State Police, ORG',
#    'Femi, PER',
#    'the News Agency of Nigeria, ORG'],
#   '1550': ['August 5th, DATE'],
#   '1551': ['Joseph, PER'],
#   '1553': ['Evans, PER'],
#   '1555': ['nine days, DATE'],
#   '1556': ['yesterday, DATE'],
#   '1560': ['one, CARDINAL', 'Dauda Wale, PER', 'One, CARDINAL'],
#   '1562': ['Nnamdi Kanu, PER'],
#   '1563': ['Onitsha, LOC', 'today, DATE'],
#   '1564': ['Buhari, PER', 'Osibanjo, PER', '2019, DATE'],
#   '1566': ['Nigeria, LOC'],
#   '1567': ['Boko Haram, ORG'],
#   '1568': ['Aisha Wakil, PER',
#    'BBC Igbo, NORP',
#    'Boko Haram, ORG',
#    'today, DATE'],
#   '1569': ['Nigeria, LOC', 'nineteen years, DATE', 'Nigeria, LOC'],
#   '1570': ['Abaribe, PER', 'the year 2018, DATE'],
#   '1572': ['World Cup, EVENT', 'Super Eagles, ORG', 'quarter, CARDINAL'],
#   '1573': ['one hundred and forty, CARDINAL', 'IBOP, ORG', 'Owerri, LOC'],
#   '1574': ['today, DATE'],
#   '1576': ['Owerri, LOC'],
#   '1577': ['2018, DATE'],
#   '1579': ['Five, CARDINAL',
#    'Regina Pacis, ORG',
#    'Onitsha, LOC',
#    '2018, DATE'],
#   '1581': ['3, CARDINAL', 'January 1, DATE'],
#   '1599': ['Olueze Ukaejuoha, PER', 'Umuakara, LOC', 'BBC Igbo, NORP'],
#   '1601': ['Akokwa village, LOC', 'Imo State, LOC'],
#   '1620': ['2019, DATE', '-Muhammadu Buhari, PER'],
#   '1621': ['Nigeria, LOC', 'Muhammadu Buhari, PER', 'second, ORDINAL'],
#   '1622': ['Muhammadu Buhari, PER'],
#   '1623': ['Muhammadu Buhari, PER', 'Nigeria, LOC', 'third, ORDINAL'],
#   '1624': ['first, ORDINAL',
#    'December 1983, DATE',
#    '1984, DATE',
#    'Nigerian, NORP',
#    'Buhari, PER',
#    '1985, DATE'],
#   '1625': ['BBC, ORG'],
#   '1626': ['Buhari, PER',
#    'democratic era, DATE',
#    '2015, DATE',
#    'three, CARDINAL'],
#   '1627': ['Buhari, PER'],
#   '1628': ['Buhari, PER'],
#   '1629': ['age 76, DATE', '2015, DATE', 'Niger, LOC'],
#   '1630': ['Four years, DATE'],
#   '1631': ['Boko Haram, ORG',
#    'Nigeria, LOC',
#    'Islamic, NORP',
#    'Northern Nigeria, LOC',
#    'Buhari, PER'],
#   '1632': ['Buhari, PER',
#    'PDP,, ORG',
#    'Atiku Abubakar, PER',
#    'Islam, NORP',
#    'Northern Nigeria, LOC',
#    'Buhari, PER'],
#   '1633': ['Buhari, PER',
#    'All Progressive Congress, ORG',
#    'APC, ORG',
#    'Nigerian, NORP'],
#   '1635': ['2, CARDINAL', 'Nnamdi Kanu, PER', 'Buratai, PER'],
#   '1637': ['2019, DATE'],
#   '1639': ['BBC, ORG'],
#   '1642': ['Nigeria, LOC',
#    'Independ National Electoral Commission, ORG',
#    'more than seventy, CARDINAL',
#    '2019, DATE',
#    'BBC Igob, ORG'],
#   '1647': ['1, CARDINAL', 'Yemi Osibanjo, PER'],
#   '1648': ['Buhari, PER',
#    'Osibanjo, PER',
#    'Nigeria, LOC',
#    '2015, DATE',
#    'All Progressive Congress, ORG'],
#   '1649': ['Muhammadu Buhari, PER'],
#   '1650': ['December 17 1942, DATE'],
#   '1651': ['Nigeria, LOC', 'two, CARDINAL'],
#   '1652': ['three, CARDINAL', '2003, 2007, DATE', '2011, DATE', '2015, DATE'],
#   '1654': ['Osibanjo, PER'],
#   '1655': ['March 8 1957, DATE'],
#   '1656': ['Redeemed Christian Church of God, ORG', 'RCCG, ORG'],
#   ...},
#  6632)

# %% [markdown]
# **Creating the mapping dictionary for future use**
#
# There will be two-steps:
# 1. Automatic: Look for the entity in the Igbo text. If found, apply the same tag to the Igbo version else indicate "Not found!"
#
# 2. Manual: Look for all the entities not found in the `mapping_dict` and manually insert them

# %%
# #  '1621': ['Nigeria, LOC', 'Muhammadu Buhari, PER', 'second, ORDINAL'],
# count_translate, found_count = 0, 0
# mapping_dict = {}
# for i, tagged in tagged_entities.items():
#   for entity_tag in tagged:
#     try:
#       entity, tag = entity_tag.rsplit(', ', 1)
#       found = ig_text[int(i)].find(entity)
#       if found>=0:
#         #transfer the Igbo tags
#         # ig_text[int(i)] = ig_text[int(i)].replace(entity, f"[{entity} - {tag}]")
#         if entity.lower() not in mapping_dict:
#           mapping_dict[entity.lower()] = {
#             'ig':entity.lower(),
#             'tag':{tag}}
#           found_count+=1
#       else:
#         if entity.lower() not in mapping_dict:
#           mapping_dict[entity.lower()] = {
#             'ig': f'Not found line {i}',
#             'tag':{tag}}
#           count_translate+=1
#     except:
#         print(f"Line {i}: Could not process '{entity}':\n{ig_text[int(i)]}\n")
# print(count_translate, found_count)

# %%
# count the remaining entities not found
def count_not_found():
  return sum([values['ig'].startswith('Not found') for entity, values in mapping_dict.items()])

#save the current version of mapping dictionary
def save_dict(m_dict):
  with open('mapping_dict.pkl', 'wb') as handle:
    pickle.dump(m_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
  print("Mapping dictionary successfully saved to 'mapping_dict.pkl'")

#load the latest version of the mapping dictionary
def load_dict(fname_pkl):
  with open(fname_pkl, 'rb') as handle:
    return pickle.load(handle)

# %% [markdown]
# **Correcting the Mapping Dictionary**

# %%
for entity, values in mapping_dict.items():
  if values['ig'].startswith('Not found'):
    index = int(values['ig'].rsplit(' ',1)[1])
    print(f"Line {index}: {entity}\n-{tagged_entities[str(index)]}\n-{ig_text[index].lower()}")
    ig_entity = input('Enter Igbo entity: ')
    if ig_entity.lower() != 'exit':
      mapping_dict[entity]['ig'] = ig_entity
      print(f"Remaining: {count_not_found()}")
    else:
      break
# Out:
# Line 2461: the ministry of national planning
# -['the ministry of national planning, ORG']
# -"mana ngalaba na-ahụ maka nhazi, - nke a na-akpọ ministry of national planning n'asụsụ bekee - kwuru na ihe niile ndị omeiwu kwesịọrị iji hazie bọjeetị dị n'ime akwụkwọ enyere ha.")
# Enter Igbo entity: ministry of national planning
# Remaining: 1746
# Line 2462: november last year
# -['Ben Akabueze, PER', 'november last year, DATE', 'Muhammadu Buhari, PER']
# -"ben akabueze, bụ onyeisi ngalaba na-ahazi mkpata na mmefu kwuru na ihe niile ndi omeiwu chọrọ dị n'akwụkwọ onyeisiala muhammadu buhari nyere ndị omeiwu n'ọnwa nọvemba nke afọ gara aga.")
# Enter Igbo entity: nọvemba nke afọ gara aga
# Remaining: 1745
# Line 2465: the ministry of finances
# -['the ministry of finances, ORG', 'Nigeria, LOC']
# -"ndị ọkachamara n'ihe banyere akụnaụba obodo na-ekwu na naịjirịa agaghị ahazi akụnauba obodo ọfụma ma ya bụrụ na bọjeetị a apụtaghị.")
# Enter Igbo entity: exit

# %% [markdown]
# **Updating the mapping dictionary**

# %%
update_mdict = input('Do you want to update mapping dictionary? [Y/N]')
if update_mdict.lower() == 'y':
  save_dict(mapping_dict)
# Out:
# Do you want to update mapping dictionary? [Y/N]y
# Mapping dictionary successfully saved to 'mapping_dict.pkl'

# %% [markdown]
# **Loading the mapping dictionary**

# %%
load_mdict = input('Do you want to load mapping dictionary? [Y/N]')
if load_mdict.lower() == 'y':
  mapping_dict = load_dict('mapping_dict.pkl')
  print("Mapping dictionary successfully loaded from 'mapping_dict.pkl'")
# Out:
# Do you want to load mapping dictionary? [Y/N]y
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-01be353806eb> in <module>
#       1 load_mdict = input('Do you want to load mapping dictionary? [Y/N]')
#       2 if load_mdict.lower() == 'y':
# ----> 3   mapping_dict = load_dict('mapping_dict.pkl')
#       4   print("Mapping dictionary successfully loaded from 'mapping_dict.pkl'")
#
# <ipython-input-7-bc2b9fc848d5> in load_dict(fname_pkl)
#      11 #load the latest version of the mapping dictionary
#      12 def load_dict(fname_pkl):
# ---> 13   with open(fname_pkl, 'rb') as handle:
#      14     return pickle.load(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mapping_dict.pkl'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Using the `mapping_dict` to transfer NER tags from Eng to Igbo**

# %%
# TODO

# %% [markdown]
# **Formatting the tagged Igbo text**

# %%
# TODO
